# %%
# %%capture
# !pip install datasets

# %% [markdown]
# ## Libraries and Dependencies

# %%
import pandas as pd
import torch
import nltk
from datasets import load_dataset
from tqdm.notebook import tqdm

# The models the authors used:
from transformers import BertForMaskedLM, BertTokenizer

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DEVICE
# Out:
# device(type='cuda')

# %% [markdown]
# ## Algorithm Implementation

# %%
def mask_sentence(sentence, mask_token, i, M, L_min):
    return [mask_token
            if (j - i) % M == 0
            and (len(sentence[j]) >= L_min
                 or sentence[j].startswith('##')
                 or sentence[min(j+1, len(sentence)-1)].startswith('##'))
            else sentence[j]
            for j in range(len(sentence))]

# %%
def BLANC_help(sentence, translation, model, tokenizer, M=6, L_min=4, sep='[SEP]', device='cpu'):
    """
    Calculates BLANC score between a given sentence and its translation using a specified model.

    Parameters:
    - sentence (List[str]): A tokenized sentence.
    - translation (List[str]): The tokenized translation.
    - model: BERT-type model
    - tokenizer: The tokenizer associated with the model used.
    - M (int): Parameter M for the algorithm (default is 6).
    - L_min (int): Minimum length requirement for masked words (default is 4).
    - sep (str): Separator between the inference help (filler/summary) and a sentence from the text (default is '[SEP]').

    Returns:
    - float: BLANC score for the given sentence and its translation.
    """

    filler = ['.'] * len(translation)
    S = [[0, 0], [0, 0]]

    for i in range(M):
        masked_sentence = mask_sentence(sentence, tokenizer.mask_token, i, M, L_min)

        input_base = filler + [sep] + masked_sentence
        input_help = translation + [sep] + masked_sentence

        tokenized_input_base = torch.tensor(tokenizer.convert_tokens_to_ids(input_base)).to(device) # Shape: [sequence_length]
        tokenized_input_help = torch.tensor(tokenizer.convert_tokens_to_ids(input_help)).to(device) # Shape: [sequence_length]

        out_base = model(input_ids=tokenized_input_base.unsqueeze(0)).logits  # Shape: [1, sequence_length, model_vocab_size]
        out_help = model(input_ids=tokenized_input_help.unsqueeze(0)).logits  # Shape: [1, sequence_length, model_vocab_size]

        out_base = torch.argmax(out_base.squeeze(0), dim=-1)  # Shape: [sequence_length]
        out_help = torch.argmax(out_help.squeeze(0), dim=-1)  # Shape: [sequence_length]

        masked_tokens = [idx for idx, word in enumerate(masked_sentence) if word == tokenizer.mask_token]

        for j in masked_tokens:
            idx = len(translation + [sep]) + j
            predicted_word_base = tokenizer.convert_ids_to_tokens(out_base[idx].item())
            predicted_word_help = tokenizer.convert_ids_to_tokens(out_help[idx].item())

            # print(f'predicted_word_base[{idx - len(translation + [sep])}]: {predicted_word_base}')
            # print(f'predicted_word_help[{idx - len(translation + [sep])}]: {predicted_word_help}')
            # print(f'sentence[{j}]: {sentence[j]}')

            k = int(predicted_word_base == sentence[j])
            m = int(predicted_word_help == sentence[j])
            S[k][m] += 1


    B = (S[0][1] - S[1][0]) / (S[0][0] + S[1][1] + S[0][1] + S[1][0])

    return B

# %%
def study_results(dataset, scores, score_lower_bound=-1, score_upper_bound=1, verbose=False):
    num_examples = 0
    num_scores = dataset.shape[0]
    for idx, score in enumerate(scores[:num_scores]):
        if score_lower_bound <= score < score_upper_bound:
            num_examples += 1
            if dataset.shape[1] == 3:
                print(f'Example {idx}   score: {score}   annotator score: {dataset.iloc[idx, 2]}')
            else:
                print(f'Example {idx}   score: {score}   annotator score: -')
            if verbose:
                print(f'Sentence: {dataset.iloc[idx, 0]}')
                print(f'Translation: {dataset.iloc[idx, 1]}')
            print('-' * 100)
    print(f'{num_examples}/{dataset.shape[0]} scores were between {score_lower_bound} and {score_upper_bound}.')

# %% [markdown]
# ## Datasets

# %%
# English - French
en_fr_ds = load_dataset('news_commentary', 'en-fr', split='train')

# English - Persian (Farsi)
en_fa_ds = load_dataset('persiannlp/parsinlu_translation_en_fa', split='train')

# English - Persian (with annotator scores)
en_fa_with_scores = pd.read_csv('/content/en-fa(0-55)_with_grades.csv', index_col=0)
en_fa_with_scores.head()
# Out:
#                                               source  \
# 0  Due Thank You note by Egyptian blogger Abdel M...
# 1  He was extremely surprised and happy to receiv...
# 2         Monem blogs under the name of “Ana Ikwan”.
# 3  On December 16, 2006, the Supreme Administrati...
# 4  Finally a call to Renew old Friendships: Tarek...
#
#                                              targets  Score
# 0  بلاگر مصری عبدل منعم محمود (عربی) پس از آزاد ش...    3.0
# 1  وی همچنین از دریافت تعداد بسیار زیادی پیام تبر...    3.0
# 2    منعم به دلیل اتهامات سیاسی ۴۵ روز در زندان بود.    0.0
# 3  در ۱۶ دسامبر ۲۰۰۶ شورای عالی اداری مصر که دولت...    2.0
# 4  رانندگان مترو برای اعتراض به زخمی شدن یکی از ه...    0.0

# %% [markdown]
# ## Model and Tokenizer

# %%
# %%capture
mbert_model = BertForMaskedLM.from_pretrained('bert-base-multilingual-uncased').to(DEVICE)
mbert_tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased', do_lower_case = True)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ## Preprocessing

# %%
# English - French

en_fr_ds = en_fr_ds.map(lambda example: example['translation'])\
                   .remove_columns(['id', 'translation'])\
                   .rename_column('en', 'sentence')\
                   .rename_column('fr', 'translation')\
                   .select(range(300))

# Tokenization
en_fr_sentences = [mbert_tokenizer.tokenize(sentence)
                   for sentence in en_fr_ds['sentence']]  # (List[List[str]])

en_fr_translations = [mbert_tokenizer.tokenize(translation)
                      for translation in en_fr_ds['translation']] # (List[List[str]])

# %%
# English - Persian (Farsi)

# Removing the 'category' column
en_fa_ds = en_fa_ds.remove_columns(['category'])

# Removing list encapsulation
en_fa_ds = en_fa_ds.map(lambda example: {'targets': example['targets'][0]}, num_proc=4)

# Filtering out rows with the '\u200c' symbol and those where the length of either source or targets is less than a threshold
length_threshold = 30
filtered_en_fa_ds = en_fa_ds.filter(
    lambda example: '\u200c' not in example['targets']
                    and len(example['source']) >= length_threshold
                    and len(example['targets']) >= length_threshold
                    and 'Global Voices' not in example['source'], # Headlines. Very short and the 'Global Voices' part is never translated
    num_proc=4)

en_fa_ds = filtered_en_fa_ds.rename_column('source', 'sentence')\
                            .rename_column('targets', 'translation')\
                            .select(range(300))

# Tokenization
en_fa_sentences = [mbert_tokenizer.tokenize(sentence)
                   for sentence in en_fa_ds['sentence']]  # (List[List[str]])

en_fa_translations = [mbert_tokenizer.tokenize(translation)
                      for translation in en_fa_ds['translation']] # (List[List[str]])

# %% [markdown]
# ## Running the Program

# %% [markdown]
# English - French

# %%
BLANC_help(en_fr_translations[1], en_fr_sentences[1], mbert_model, mbert_tokenizer, device=DEVICE)
# Out:
# 0.35714285714285715

# %%
# %%time
en_fr_scores = [BLANC_help(translation, sentence, mbert_model, mbert_tokenizer, device=DEVICE)
                for translation, sentence in tqdm(zip(en_fr_translations, en_fr_sentences), total=len(en_fr_sentences))]
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# CPU times: user 1min 3s, sys: 203 ms, total: 1min 3s
# Wall time: 1min 10s

# %%
en_fr_scores
# Out:
# [0.0,
#  0.35714285714285715,
#  0.125,
#  0.21621621621621623,
#  -0.2,
#  0.09523809523809523,
#  0.0,
#  0.05555555555555555,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  0.07692307692307693,
#  0.23076923076923078,
#  0.10526315789473684,
#  0.0,
#  0.2857142857142857,
#  0.10256410256410256,
#  0.0,
#  0.0,
#  0.13043478260869565,
#  0.1836734693877551,
#  0.17647058823529413,
#  0.0,
#  0.02857142857142857,
#  0.13043478260869565,
#  0.25,
#  0.08,
#  0.09523809523809523,
#  0.04,
#  0.0,
#  0.07407407407407407,
#  0.05263157894736842,
#  0.0,
#  0.0,
#  0.0,
#  0.08333333333333333,
#  0.0,
#  0.0,
#  0.0,
#  0.08333333333333333,
#  0.0,
#  0.0,
#  0.0,
#  0.16666666666666666,
#  0.13043478260869565,
#  0.0,
#  0.16666666666666666,
#  0.10344827586206896,
#  0.07692307692307693,
#  0.15384615384615385,
#  0.0,
#  0.26666666666666666,
#  0.18181818181818182,
#  0.029411764705882353,
#  0.10526315789473684,
#  0.13333333333333333,
#  0.16129032258064516,
#  0.21428571428571427,
#  0.15625,
#  0.14285714285714285,
#  0.05405405405405406,
#  0.1388888888888889,
#  0.16666666666666666,
#  0.14285714285714285,
#  0.0,
#  0.05555555555555555,
#  0.25,
#  0.11904761904761904,
#  0.09523809523809523,
#  0.23333333333333334,
#  0.16666666666666666,
#  0.1875,
#  0.3333333333333333,
#  0.043478260869565216,
#  0.0,
#  0.1111111111111111,
#  0.058823529411764705,
#  0.0625,
#  0.03571428571428571,
#  0.13333333333333333,
#  0.13636363636363635,
#  0.1875,
#  0.0625,
#  0.02564102564102564,
#  0.07142857142857142,
#  -0.058823529411764705,
#  0.0,
#  0.14285714285714285,
#  0.10526315789473684,
#  -0.14285714285714285,
#  0.03125,
#  0.058823529411764705,
#  0.07692307692307693,
#  0.08333333333333333,
#  0.0,
#  0.125,
#  0.13333333333333333,
#  0.02631578947368421,
#  0.041666666666666664,
#  0.06666666666666667,
#  0.2,
#  0.13333333333333333,
#  0.6666666666666666,
#  0.1875,
#  0.07142857142857142,
#  0.0,
#  0.045454545454545456,
#  0.08695652173913043,
#  0.13793103448275862,
#  -0.05,
#  0.3333333333333333,
#  0.16666666666666666,
#  0.07142857142857142,
#  0.11428571428571428,
#  0.02857142857142857,
#  0.18181818181818182,
#  0.05,
#  0.0,
#  0.15151515151515152,
#  0.14285714285714285,
#  0.0,
#  0.25,
#  0.1111111111111111,
#  0.12,
#  0.0,
#  0.15384615384615385,
#  0.09523809523809523,
#  0.14705882352941177,
#  0.32142857142857145,
#  0.0,
#  0.0975609756097561,
#  0.08,
#  0.23529411764705882,
#  0.25,
#  0.14285714285714285,
#  -0.0625,
#  -0.07142857142857142,
#  0.25,
#  0.07317073170731707,
#  0.1875,
#  0.0,
#  0.08333333333333333,
#  0.09090909090909091,
#  0.13333333333333333,
#  0.17777777777777778,
#  0.1111111111111111,
#  0.47058823529411764,
#  0.13513513513513514,
#  0.13043478260869565,
#  0.14285714285714285,
#  0.061224489795918366,
#  0.3333333333333333,
#  0.0,
#  0.12121212121212122,
#  0.1,
#  0.5,
#  0.06557377049180328,
#  0.16666666666666666,
#  0.2,
#  -0.02857142857142857,
#  0.14285714285714285,
#  -0.025,
#  0.03571428571428571,
#  0.0,
#  0.0,
#  -0.125,
#  0.0,
#  0.15384615384615385,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  -0.058823529411764705,
#  0.25,
#  0.0,
#  0.047619047619047616,
#  0.2857142857142857,
#  0.10526315789473684,
#  0.045454545454545456,
#  0.375,
#  0.0625,
#  0.20512820512820512,
#  0.375,
#  0.25,
#  0.1111111111111111,
#  0.32,
#  0.11940298507462686,
#  0.08,
#  0.0,
#  0.0,
#  0.0,
#  0.0625,
#  0.18518518518518517,
#  0.047619047619047616,
#  0.21052631578947367,
#  0.2222222222222222,
#  0.2,
#  0.25,
#  0.5,
#  0.06896551724137931,
#  0.05555555555555555,
#  0.13157894736842105,
#  0.1,
#  0.0,
#  0.13043478260869565,
#  0.1,
#  0.08823529411764706,
#  0.23076923076923078,
#  0.125,
#  0.02564102564102564,
#  0.08928571428571429,
#  0.10714285714285714,
#  0.2,
#  0.23255813953488372,
#  0.14814814814814814,
#  0.11428571428571428,
#  0.045454545454545456,
#  0.17543859649122806,
#  0.07692307692307693,
#  0.10416666666666667,
#  0.28,
#  0.11538461538461539,
#  0.07142857142857142,
#  0.15384615384615385,
#  0.2727272727272727,
#  0.0,
#  0.08108108108108109,
#  -0.1,
#  0.23076923076923078,
#  0.043478260869565216,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.0,
#  0.32,
#  0.16666666666666666,
#  0.125,
#  0.2,
#  0.18518518518518517,
#  0.19047619047619047,
#  0.10526315789473684,
#  0.08108108108108109,
#  0.09090909090909091,
#  0.13636363636363635,
#  0.17647058823529413,
#  0.24242424242424243,
#  0.1038961038961039,
#  0.07216494845360824,
#  0.25,
#  0.047619047619047616,
#  0.20588235294117646,
#  0.16666666666666666,
#  0.06666666666666667,
#  0.2,
#  0.12,
#  0.05,
#  0.09090909090909091,
#  0.2631578947368421,
#  0.11538461538461539,
#  0.06666666666666667,
#  0.0,
#  0.25,
#  0.23404255319148937,
#  0.5714285714285714,
#  0.25,
#  0.2727272727272727,
#  0.22727272727272727,
#  0.14285714285714285,
#  0.0,
#  0.17391304347826086,
#  0.2,
#  0.11764705882352941,
#  0.16666666666666666,
#  0.29411764705882354,
#  0.125,
#  1.0,
#  0.23809523809523808,
#  0.23255813953488372,
#  0.15,
#  0.08695652173913043,
#  0.18181818181818182,
#  0.05263157894736842,
#  0.18181818181818182,
#  0.2608695652173913,
#  0.1724137931034483,
#  0.2,
#  0.2777777777777778,
#  0.0,
#  0.5384615384615384,
#  0.0,
#  0.05194805194805195,
#  0.0392156862745098,
#  0.011235955056179775,
#  0.0625,
#  0.08108108108108109,
#  0.0392156862745098,
#  0.10344827586206896,
#  0.125,
#  0.08333333333333333,
#  0.05263157894736842]

# %% [markdown]
# English - Persian (Farsi)

# %%
BLANC_help(en_fa_translations[1], en_fa_sentences[1], mbert_model, mbert_tokenizer, device=DEVICE)
# Out:
# 0.25

# %%
# %%time
en_fa_scores = [BLANC_help(translation, sentence, mbert_model, mbert_tokenizer, device=DEVICE)
                for translation, sentence in tqdm(zip(en_fa_translations, en_fa_sentences), total=len(en_fa_sentences))]
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# CPU times: user 56.4 s, sys: 231 ms, total: 56.6 s
# Wall time: 1min

# %%
en_fa_scores
# Out:
# [0.07407407407407407,
#  0.25,
#  0.1,
#  0.047619047619047616,
#  0.045454545454545456,
#  0.0,
#  0.0,
#  0.0625,
#  0.043478260869565216,
#  0.1875,
#  0.07142857142857142,
#  0.034482758620689655,
#  0.0,
#  0.0,
#  0.0,
#  0.07692307692307693,
#  0.2,
#  0.09090909090909091,
#  0.4,
#  0.19047619047619047,
#  0.05555555555555555,
#  0.0,
#  0.0,
#  0.0,
#  -0.046511627906976744,
#  0.0,
#  0.06666666666666667,
#  -0.1111111111111111,
#  0.11538461538461539,
#  0.041666666666666664,
#  -0.13333333333333333,
#  0.0,
#  0.02564102564102564,
#  0.0,
#  -0.09090909090909091,
#  -0.05,
#  0.0,
#  0.09523809523809523,
#  0.0625,
#  0.14285714285714285,
#  0.0,
#  0.1,
#  0.11764705882352941,
#  -0.23076923076923078,
#  0.21052631578947367,
#  0.03571428571428571,
#  -0.15384615384615385,
#  0.07692307692307693,
#  0.0,
#  0.0,
#  0.09090909090909091,
#  0.03571428571428571,
#  0.0,
#  0.06896551724137931,
#  0.05405405405405406,
#  0.0,
#  0.14285714285714285,
#  0.0,
#  0.05,
#  -0.034482758620689655,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  0.06451612903225806,
#  0.24,
#  0.08333333333333333,
#  0.0,
#  -0.08333333333333333,
#  0.06,
#  0.03571428571428571,
#  0.19047619047619047,
#  0.17391304347826086,
#  0.058823529411764705,
#  0.0,
#  0.0,
#  0.0,
#  0.07407407407407407,
#  -0.1,
#  0.04,
#  0.0,
#  0.16666666666666666,
#  0.0625,
#  0.0,
#  0.058823529411764705,
#  0.034482758620689655,
#  0.0,
#  0.125,
#  0.0,
#  0.09090909090909091,
#  0.1875,
#  0.1,
#  0.0,
#  0.0,
#  0.0,
#  0.12,
#  0.15,
#  0.05263157894736842,
#  0.09523809523809523,
#  0.045454545454545456,
#  0.13636363636363635,
#  0.21428571428571427,
#  0.0,
#  0.023809523809523808,
#  0.025,
#  0.041666666666666664,
#  0.11538461538461539,
#  0.09523809523809523,
#  0.038461538461538464,
#  0.0,
#  0.06818181818181818,
#  0.06896551724137931,
#  -0.06666666666666667,
#  -0.038461538461538464,
#  0.043478260869565216,
#  0.05714285714285714,
#  0.0,
#  0.0,
#  -0.043478260869565216,
#  0.0,
#  0.0,
#  0.0,
#  -0.034482758620689655,
#  0.11764705882352941,
#  -0.047619047619047616,
#  0.02127659574468085,
#  -0.25,
#  -0.05555555555555555,
#  0.0,
#  -0.06666666666666667,
#  0.037037037037037035,
#  0.0,
#  0.030303030303030304,
#  0.045454545454545456,
#  0.0,
#  0.07692307692307693,
#  0.034482758620689655,
#  0.0,
#  0.047619047619047616,
#  0.35714285714285715,
#  0.14814814814814814,
#  0.09090909090909091,
#  0.0,
#  -0.045454545454545456,
#  0.0,
#  0.0,
#  0.05263157894736842,
#  0.15,
#  0.05263157894736842,
#  0.0,
#  0.0,
#  0.0,
#  0.125,
#  0.0,
#  0.1,
#  -0.045454545454545456,
#  0.08,
#  -0.037037037037037035,
#  0.0,
#  -0.06666666666666667,
#  0.0,
#  -0.038461538461538464,
#  0.047619047619047616,
#  0.2857142857142857,
#  0.08333333333333333,
#  0.08,
#  -0.02564102564102564,
#  0.07692307692307693,
#  0.18181818181818182,
#  0.0967741935483871,
#  0.0,
#  0.05555555555555555,
#  0.08695652173913043,
#  -0.03125,
#  0.15789473684210525,
#  0.11538461538461539,
#  0.02702702702702703,
#  0.0,
#  0.05,
#  -0.06060606060606061,
#  0.0,
#  -0.05,
#  -0.05555555555555555,
#  0.0,
#  0.05263157894736842,
#  0.06666666666666667,
#  0.0,
#  0.17647058823529413,
#  0.07142857142857142,
#  0.14285714285714285,
#  0.1,
#  0.125,
#  -0.09090909090909091,
#  0.3,
#  -0.045454545454545456,
#  0.0,
#  0.0,
#  0.11428571428571428,
#  -0.07407407407407407,
#  0.0,
#  0.0,
#  0.125,
#  0.08333333333333333,
#  0.0,
#  0.07692307692307693,
#  0.1,
#  0.06666666666666667,
#  0.045454545454545456,
#  0.18181818181818182,
#  0.09523809523809523,
#  0.0,
#  0.0,
#  -0.08333333333333333,
#  0.04,
#  -0.03225806451612903,
#  0.0,
#  0.0,
#  0.25,
#  0.0,
#  -0.09375,
#  0.08333333333333333,
#  0.0,
#  0.0,
#  -0.041666666666666664,
#  0.2,
#  0.0,
#  0.0,
#  0.058823529411764705,
#  0.027777777777777776,
#  0.0,
#  0.09090909090909091,
#  0.0,
#  0.030303030303030304,
#  0.0,
#  0.0,
#  0.023809523809523808,
#  0.02857142857142857,
#  0.0,
#  0.05263157894736842,
#  0.0,
#  0.07407407407407407,
#  0.11538461538461539,
#  0.041666666666666664,
#  -0.043478260869565216,
#  -0.041666666666666664,
#  0.0,
#  0.07142857142857142,
#  0.058823529411764705,
#  0.11764705882352941,
#  0.07142857142857142,
#  0.08333333333333333,
#  0.0,
#  0.7142857142857143,
#  0.1111111111111111,
#  0.05555555555555555,
#  0.03125,
#  0.0,
#  0.0,
#  0.0,
#  -0.058823529411764705,
#  0.15384615384615385,
#  0.17142857142857143,
#  0.037037037037037035,
#  0.13636363636363635,
#  -0.045454545454545456,
#  0.02631578947368421,
#  0.0,
#  0.08333333333333333,
#  0.0,
#  0.0,
#  0.125,
#  0.05263157894736842,
#  0.0,
#  0.05555555555555555,
#  0.09523809523809523,
#  0.2857142857142857,
#  0.13333333333333333,
#  0.1,
#  0.0,
#  0.2727272727272727,
#  0.2,
#  0.043478260869565216,
#  0.0,
#  0.0,
#  -0.06666666666666667,
#  0.14285714285714285,
#  -0.045454545454545456,
#  0.1111111111111111,
#  0.047619047619047616,
#  0.02631578947368421,
#  -0.125,
#  0.0,
#  0.16666666666666666,
#  -0.23076923076923078,
#  0.0,
#  -0.045454545454545456,
#  0.038461538461538464,
#  -0.07142857142857142,
#  0.07142857142857142,
#  0.0]

# %% [markdown]
# ## Analysis of the results

# %%
# Negative scores in the subdataset with annotator scores
study_results(en_fa_with_scores, en_fa_scores, score_upper_bound=0)
# Out:
# Example 24   score: -0.046511627906976744   annotator score: 2.0
# ----------------------------------------------------------------------------------------------------
# Example 27   score: -0.1111111111111111   annotator score: 3.0
# ----------------------------------------------------------------------------------------------------
# Example 30   score: -0.13333333333333333   annotator score: 2.0
# ----------------------------------------------------------------------------------------------------
# Example 34   score: -0.09090909090909091   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 35   score: -0.05   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 43   score: -0.23076923076923078   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 46   score: -0.15384615384615385   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# 7/56 scores were between -1 and 0.

# %%
# 0.0 scores in the subdataset with annotator scores
study_results(en_fa_with_scores, en_fa_scores, score_lower_bound=0, score_upper_bound=0.01)
# Out:
# Example 5   score: 0.0   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 6   score: 0.0   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 12   score: 0.0   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 13   score: 0.0   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 14   score: 0.0   annotator score: 4.0
# ----------------------------------------------------------------------------------------------------
# Example 21   score: 0.0   annotator score: 3.0
# ----------------------------------------------------------------------------------------------------
# Example 22   score: 0.0   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 23   score: 0.0   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 25   score: 0.0   annotator score: 2.0
# ----------------------------------------------------------------------------------------------------
# Example 31   score: 0.0   annotator score: 4.0
# ----------------------------------------------------------------------------------------------------
# Example 33   score: 0.0   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 36   score: 0.0   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 40   score: 0.0   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 48   score: 0.0   annotator score: 2.0
# ----------------------------------------------------------------------------------------------------
# Example 49   score: 0.0   annotator score: 4.0
# ----------------------------------------------------------------------------------------------------
# Example 52   score: 0.0   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 55   score: 0.0   annotator score: 4.0
# ----------------------------------------------------------------------------------------------------
# 17/56 scores were between 0 and 0.01.

# %%
# Positive scores in the subdataset with annotator scores
study_results(en_fa_with_scores, en_fa_scores, score_lower_bound=0.01)
# Out:
# Example 0   score: 0.07407407407407407   annotator score: 3.0
# ----------------------------------------------------------------------------------------------------
# Example 1   score: 0.25   annotator score: 3.0
# ----------------------------------------------------------------------------------------------------
# Example 2   score: 0.1   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 3   score: 0.047619047619047616   annotator score: 2.0
# ----------------------------------------------------------------------------------------------------
# Example 4   score: 0.045454545454545456   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 7   score: 0.0625   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 8   score: 0.043478260869565216   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 9   score: 0.1875   annotator score: 4.0
# ----------------------------------------------------------------------------------------------------
# Example 10   score: 0.07142857142857142   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 11   score: 0.034482758620689655   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 15   score: 0.07692307692307693   annotator score: 4.0
# ----------------------------------------------------------------------------------------------------
# Example 16   score: 0.2   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 17   score: 0.09090909090909091   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 18   score: 0.4   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 19   score: 0.19047619047619047   annotator score: 4.0
# ----------------------------------------------------------------------------------------------------
# Example 20   score: 0.05555555555555555   annotator score: 3.0
# ----------------------------------------------------------------------------------------------------
# Example 26   score: 0.06666666666666667   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 28   score: 0.11538461538461539   annotator score: 2.0
# ----------------------------------------------------------------------------------------------------
# Example 29   score: 0.041666666666666664   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 32   score: 0.02564102564102564   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 37   score: 0.09523809523809523   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 38   score: 0.0625   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 39   score: 0.14285714285714285   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 41   score: 0.1   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 42   score: 0.11764705882352941   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 44   score: 0.21052631578947367   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 45   score: 0.03571428571428571   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 47   score: 0.07692307692307693   annotator score: 4.0
# ----------------------------------------------------------------------------------------------------
# Example 50   score: 0.09090909090909091   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 51   score: 0.03571428571428571   annotator score: 2.0
# ----------------------------------------------------------------------------------------------------
# Example 53   score: 0.06896551724137931   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 54   score: 0.05405405405405406   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# 32/56 scores were between 0.01 and 1.

# %%
# Scores higher than 0.2 in the subdataset with annotator scores
study_results(en_fa_with_scores, en_fa_scores, score_lower_bound=0.2)
# Out:
# Example 1   score: 0.25   annotator score: 3.0
# ----------------------------------------------------------------------------------------------------
# Example 16   score: 0.2   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# Example 18   score: 0.4   annotator score: 1.0
# ----------------------------------------------------------------------------------------------------
# Example 44   score: 0.21052631578947367   annotator score: 0.0
# ----------------------------------------------------------------------------------------------------
# 4/56 scores were between 0.2 and 1.

# %%
# Negative scores in the complete dataset
study_results(en_fa_ds, en_fa_scores, score_upper_bound=0)
# Out:
# Example 24   score: -0.046511627906976744   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 27   score: -0.1111111111111111   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 30   score: -0.13333333333333333   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 34   score: -0.09090909090909091   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 35   score: -0.05   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 43   score: -0.23076923076923078   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 46   score: -0.15384615384615385   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 59   score: -0.034482758620689655   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 68   score: -0.08333333333333333   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 78   score: -0.1   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 112   score: -0.06666666666666667   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 113   score: -0.038461538461538464   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 118   score: -0.043478260869565216   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 122   score: -0.034482758620689655   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 124   score: -0.047619047619047616   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 126   score: -0.25   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 127   score: -0.05555555555555555   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 129   score: -0.06666666666666667   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 143   score: -0.045454545454545456   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 155   score: -0.045454545454545456   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 157   score: -0.037037037037037035   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 159   score: -0.06666666666666667   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 161   score: -0.038461538461538464   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 166   score: -0.02564102564102564   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 173   score: -0.03125   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 179   score: -0.06060606060606061   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 181   score: -0.05   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 182   score: -0.05555555555555555   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 192   score: -0.09090909090909091   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 194   score: -0.045454545454545456   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 198   score: -0.07407407407407407   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 212   score: -0.08333333333333333   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 214   score: -0.03225806451612903   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 219   score: -0.09375   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 223   score: -0.041666666666666664   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 243   score: -0.043478260869565216   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 244   score: -0.041666666666666664   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 259   score: -0.058823529411764705   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 264   score: -0.045454545454545456   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 284   score: -0.06666666666666667   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 286   score: -0.045454545454545456   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 290   score: -0.125   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 293   score: -0.23076923076923078   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 295   score: -0.045454545454545456   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 297   score: -0.07142857142857142   annotator score: -
# ----------------------------------------------------------------------------------------------------
# 45/300 scores were between -1 and 0.

# %%
# 0.0 scores in the complete dataset
study_results(en_fa_ds, en_fa_scores, score_lower_bound=0, score_upper_bound=0.01)
# Out:
# Example 5   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 6   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 12   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 13   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 14   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 21   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 22   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 23   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 25   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 31   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 33   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 36   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 40   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 48   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 49   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 52   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 55   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 57   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 60   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 61   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 62   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 63   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 67   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 74   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 75   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 76   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 80   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 83   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 86   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 88   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 92   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 93   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 94   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 102   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 109   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 116   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 117   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 119   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 120   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 121   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 128   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 131   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 134   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 137   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 142   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 144   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 145   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 149   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 150   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 151   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 153   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 158   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 160   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 170   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 177   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 180   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 183   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 186   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 195   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 196   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 199   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 200   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 203   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 210   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 211   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 215   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 216   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 218   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 221   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 222   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 225   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 226   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 229   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 231   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 233   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 234   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 237   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 239   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 245   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 251   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 256   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 257   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 258   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 266   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 268   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 269   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 272   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 278   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 282   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 283   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 291   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 294   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 299   score: 0.0   annotator score: -
# ----------------------------------------------------------------------------------------------------
# 93/300 scores were between 0 and 0.01.

# %%
# Positive scores in the complete dataset
study_results(en_fa_ds, en_fa_scores, score_lower_bound=0.01)
# Out:
# Example 0   score: 0.07407407407407407   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 1   score: 0.25   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 2   score: 0.1   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 3   score: 0.047619047619047616   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 4   score: 0.045454545454545456   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 7   score: 0.0625   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 8   score: 0.043478260869565216   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 9   score: 0.1875   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 10   score: 0.07142857142857142   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 11   score: 0.034482758620689655   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 15   score: 0.07692307692307693   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 16   score: 0.2   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 17   score: 0.09090909090909091   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 18   score: 0.4   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 19   score: 0.19047619047619047   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 20   score: 0.05555555555555555   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 26   score: 0.06666666666666667   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 28   score: 0.11538461538461539   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 29   score: 0.041666666666666664   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 32   score: 0.02564102564102564   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 37   score: 0.09523809523809523   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 38   score: 0.0625   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 39   score: 0.14285714285714285   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 41   score: 0.1   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 42   score: 0.11764705882352941   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 44   score: 0.21052631578947367   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 45   score: 0.03571428571428571   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 47   score: 0.07692307692307693   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 50   score: 0.09090909090909091   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 51   score: 0.03571428571428571   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 53   score: 0.06896551724137931   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 54   score: 0.05405405405405406   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 56   score: 0.14285714285714285   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 58   score: 0.05   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 64   score: 0.06451612903225806   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 65   score: 0.24   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 66   score: 0.08333333333333333   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 69   score: 0.06   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 70   score: 0.03571428571428571   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 71   score: 0.19047619047619047   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 72   score: 0.17391304347826086   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 73   score: 0.058823529411764705   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 77   score: 0.07407407407407407   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 79   score: 0.04   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 81   score: 0.16666666666666666   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 82   score: 0.0625   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 84   score: 0.058823529411764705   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 85   score: 0.034482758620689655   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 87   score: 0.125   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 89   score: 0.09090909090909091   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 90   score: 0.1875   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 91   score: 0.1   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 95   score: 0.12   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 96   score: 0.15   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 97   score: 0.05263157894736842   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 98   score: 0.09523809523809523   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 99   score: 0.045454545454545456   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 100   score: 0.13636363636363635   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 101   score: 0.21428571428571427   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 103   score: 0.023809523809523808   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 104   score: 0.025   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 105   score: 0.041666666666666664   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 106   score: 0.11538461538461539   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 107   score: 0.09523809523809523   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 108   score: 0.038461538461538464   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 110   score: 0.06818181818181818   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 111   score: 0.06896551724137931   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 114   score: 0.043478260869565216   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 115   score: 0.05714285714285714   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 123   score: 0.11764705882352941   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 125   score: 0.02127659574468085   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 130   score: 0.037037037037037035   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 132   score: 0.030303030303030304   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 133   score: 0.045454545454545456   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 135   score: 0.07692307692307693   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 136   score: 0.034482758620689655   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 138   score: 0.047619047619047616   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 139   score: 0.35714285714285715   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 140   score: 0.14814814814814814   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 141   score: 0.09090909090909091   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 146   score: 0.05263157894736842   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 147   score: 0.15   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 148   score: 0.05263157894736842   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 152   score: 0.125   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 154   score: 0.1   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 156   score: 0.08   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 162   score: 0.047619047619047616   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 163   score: 0.2857142857142857   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 164   score: 0.08333333333333333   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 165   score: 0.08   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 167   score: 0.07692307692307693   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 168   score: 0.18181818181818182   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 169   score: 0.0967741935483871   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 171   score: 0.05555555555555555   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 172   score: 0.08695652173913043   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 174   score: 0.15789473684210525   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 175   score: 0.11538461538461539   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 176   score: 0.02702702702702703   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 178   score: 0.05   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 184   score: 0.05263157894736842   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 185   score: 0.06666666666666667   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 187   score: 0.17647058823529413   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 188   score: 0.07142857142857142   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 189   score: 0.14285714285714285   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 190   score: 0.1   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 191   score: 0.125   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 193   score: 0.3   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 197   score: 0.11428571428571428   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 201   score: 0.125   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 202   score: 0.08333333333333333   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 204   score: 0.07692307692307693   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 205   score: 0.1   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 206   score: 0.06666666666666667   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 207   score: 0.045454545454545456   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 208   score: 0.18181818181818182   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 209   score: 0.09523809523809523   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 213   score: 0.04   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 217   score: 0.25   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 220   score: 0.08333333333333333   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 224   score: 0.2   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 227   score: 0.058823529411764705   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 228   score: 0.027777777777777776   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 230   score: 0.09090909090909091   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 232   score: 0.030303030303030304   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 235   score: 0.023809523809523808   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 236   score: 0.02857142857142857   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 238   score: 0.05263157894736842   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 240   score: 0.07407407407407407   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 241   score: 0.11538461538461539   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 242   score: 0.041666666666666664   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 246   score: 0.07142857142857142   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 247   score: 0.058823529411764705   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 248   score: 0.11764705882352941   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 249   score: 0.07142857142857142   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 250   score: 0.08333333333333333   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 252   score: 0.7142857142857143   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 253   score: 0.1111111111111111   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 254   score: 0.05555555555555555   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 255   score: 0.03125   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 260   score: 0.15384615384615385   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 261   score: 0.17142857142857143   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 262   score: 0.037037037037037035   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 263   score: 0.13636363636363635   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 265   score: 0.02631578947368421   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 267   score: 0.08333333333333333   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 270   score: 0.125   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 271   score: 0.05263157894736842   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 273   score: 0.05555555555555555   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 274   score: 0.09523809523809523   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 275   score: 0.2857142857142857   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 276   score: 0.13333333333333333   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 277   score: 0.1   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 279   score: 0.2727272727272727   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 280   score: 0.2   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 281   score: 0.043478260869565216   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 285   score: 0.14285714285714285   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 287   score: 0.1111111111111111   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 288   score: 0.047619047619047616   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 289   score: 0.02631578947368421   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 292   score: 0.16666666666666666   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 296   score: 0.038461538461538464   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 298   score: 0.07142857142857142   annotator score: -
# ----------------------------------------------------------------------------------------------------
# 162/300 scores were between 0.01 and 1.

# %%
# Scores higher than 0.2 in the complete dataset
study_results(en_fa_ds, en_fa_scores, score_lower_bound=0.2)
# Out:
# Example 1   score: 0.25   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 16   score: 0.2   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 18   score: 0.4   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 44   score: 0.21052631578947367   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 65   score: 0.24   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 101   score: 0.21428571428571427   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 139   score: 0.35714285714285715   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 163   score: 0.2857142857142857   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 193   score: 0.3   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 217   score: 0.25   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 224   score: 0.2   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 252   score: 0.7142857142857143   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 275   score: 0.2857142857142857   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 279   score: 0.2727272727272727   annotator score: -
# ----------------------------------------------------------------------------------------------------
# Example 280   score: 0.2   annotator score: -
# ----------------------------------------------------------------------------------------------------
# 15/300 scores were between 0.2 and 1.
