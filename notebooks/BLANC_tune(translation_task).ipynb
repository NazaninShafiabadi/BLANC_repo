# %%
# %%capture
# !pip install datasets
# !pip install accelerate -U

# %% [markdown]
# ## Libraries and Dependencies

# %%
import torch
import nltk
from datasets import load_dataset, Dataset
from tqdm.notebook import tqdm
import random

# The models the authors used:
from transformers import BertForMaskedLM, BertTokenizer, logging
from transformers import TrainingArguments, Trainer

SEED = 42
random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

nltk.download('punkt')
logging.set_verbosity_error()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DEVICE
# Out:
# device(type='cuda')

# %% [markdown]
# ## Functions

# %%
class CustomDataCollator:
    def __init__(self, tokenizer):
        self.tokenizer = tokenizer

    def __call__(self, examples):
        input_ids = torch.tensor([example['input_ids'] for example in examples])
        labels = torch.tensor([example['labels'] for example in examples])

        input_ids = torch.nn.utils.rnn.pad_sequence(input_ids, batch_first=True, padding_value=self.tokenizer.pad_token_id)
        labels = torch.nn.utils.rnn.pad_sequence(labels, batch_first=True, padding_value=self.tokenizer.pad_token_id)  # -100 is the default index to ignore in the loss function

        return {'input_ids': input_ids, 'labels': labels}

# %%
def tune_model(tune_set, model, tokenizer, n_epochs):
    # metric = evaluate.load("accuracy")

    training_args = TrainingArguments(
        f"finetuned-model",
        evaluation_strategy = "no",
        learning_rate = 1e-4,
        weight_decay = 0.01,
        num_train_epochs = n_epochs,
        logging_strategy = "no"
        )

    # data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm_probability=0.15)
    data_collator = CustomDataCollator(tokenizer)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=tune_set,
        # eval_dataset= ?,
        data_collator=data_collator,
        )

    trainer.train()

    # Evaluate the model
    # eval_results = trainer.evaluate()
    # print(f"Perplexity: {math.exp(eval_results['eval_loss']):.2f}")

    return model

# %%
def mask_sentence(sentence, mask_token, i, M, L_min):
    return [mask_token
            if (j - i) % M == 0
            and (len(sentence[j]) >= L_min
                 or sentence[j].startswith('##')
                 or sentence[min(j+1, len(sentence)-1)].startswith('##'))
            else sentence[j]
            for j in range(len(sentence))]

# %%
def BLANC_tune_inference(sentence, model, model_tuned, tokenizer, p_mask=0.15, L_min=4, device='cpu'):
    """
    Compares the performance of a model fine-tuned on the 'translation' vs. a model that has never seen the translation.

    Parameters:
    - sentence (List[str]): A tokenized sentence.
    - model: BERT-type model
    - model_tuned: The fine-tuned model.
    - tokenizer: The tokenizer associated with the model used.
    - p_mask (float): Probability of masking (default is 0.15).
    - L_min (int): Minimum length requirement for masked words (default is 4).

    Returns:
    - float: BLANC_tune score showing the quality of the translation.
    """

    S = [[0, 0], [0, 0]]
    M = int(1/p_mask)

    for i in range(M):

        masked_sentence = mask_sentence(sentence, tokenizer.mask_token, i, M, L_min)
        masked_sentence_ids = torch.tensor(tokenizer.convert_tokens_to_ids(masked_sentence)).to(device) # Shape: [sequence_length]

        out_base = model(input_ids=masked_sentence_ids.unsqueeze(0)).logits  # Shape: [1, sequence_length, Bert_vocab_size]
        out_tune = model_tuned(input_ids=masked_sentence_ids.unsqueeze(0)).logits  # Shape: [1, sequence_length, Bert_vocab_size]

        out_base = torch.argmax(out_base.squeeze(0), dim=-1)  # Shape: [sequence_length]
        out_tune = torch.argmax(out_tune.squeeze(0), dim=-1)  # Shape: [sequence_length]

        masked_tokens = [idx for idx, word in enumerate(masked_sentence) if word == tokenizer.mask_token]

        for j in masked_tokens:
            predicted_word_base = tokenizer.convert_ids_to_tokens(out_base[j].item())
            predicted_word_tune = tokenizer.convert_ids_to_tokens(out_tune[j].item())

            # print(f'predicted_word_base[{j}]: {predicted_word_base}')
            # print(f'predicted_word_help[{j}]: {predicted_word_tune}')
            # print(f'sentence[{j}]: {sentence[j]}')

            k = int(predicted_word_base == sentence[j])
            m = int(predicted_word_tune == sentence[j])
            S[k][m] += 1


    B = (S[0][1] - S[1][0]) / (S[0][0] + S[1][1] + S[0][1] + S[1][0])

    return B

# %%
def BLANC_tune(sentence, translation, model_checkpoint, model, tokenizer, p_mask=0.15, L_min=4, N=10, n_epochs=3, device='cpu'):

    # Model tuning
    N_words = len(translation)
    N_mask = int(N_words * p_mask)
    set_tune = Dataset.from_dict({})

    translation_ids = tokenizer.convert_tokens_to_ids(translation)

    for _ in range(N):
        pos = [i for i, token in enumerate(translation)
               if (len(token) >= L_min
                   or token.startswith('##')
                   or translation[min(i+1, len(translation)-1)].startswith('##'))] # positions of words longer than Lmin
        random.shuffle(pos)
        while len(pos) != 0:
            # Mask words in next N_mask positions
            masked_translation = translation_ids.copy()
            for pos_to_mask in pos[:N_mask]:
                masked_translation[pos_to_mask] = tokenizer.mask_token_id
            # Add translation with masked words to set_tune
            set_tune = set_tune.add_item({"input_ids": masked_translation, 'labels': translation_ids})
            pos = pos[N_mask:]

    # Creating a fresh pre-trained model
    new_model = BertForMaskedLM.from_pretrained(model_checkpoint).to(device)
    model_tuned = tune_model(set_tune, new_model, tokenizer, n_epochs)

    # Comparing inference with model vs. model_tuned
    score = BLANC_tune_inference(sentence, model, model_tuned, tokenizer, p_mask, L_min, device)

    del new_model
    del model_tuned
    torch.cuda.empty_cache()

    return score

# %%
import json

def add_results_to_json(new_data, file_path = "./results.json"):
    try:
        with open(file_path, 'r') as json_file:
            existing_data = json.load(json_file)
    except FileNotFoundError:
        existing_data = {}

    for key, value in new_data.items():
        existing_data[key] = value

    with open(file_path, 'w') as json_file:
        json.dump(existing_data, json_file, indent=2)

    print(f"Data has been added to {file_path}")

# %% [markdown]
# ## Datasets

# %%
# English - French
en_fr_ds = load_dataset('news_commentary', 'en-fr', split='train')

# English - Persian (Farsi)
en_fa_ds = load_dataset('persiannlp/parsinlu_translation_en_fa', split='train')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# ## Model and Tokenizer

# %%
# %%capture
model_checkpoint = 'bert-base-multilingual-uncased'
mbert_model = BertForMaskedLM.from_pretrained(model_checkpoint).to(DEVICE)
mbert_tokenizer = BertTokenizer.from_pretrained(model_checkpoint, do_lower_case=True, use_fast=True)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# English - French

# %%
# English - French

en_fr_ds = en_fr_ds.map(lambda example: example['translation'])\
                   .remove_columns(['id', 'translation'])\
                   .rename_column('en', 'sentence')\
                   .rename_column('fr', 'translation')\
                   .select(range(300))

# Tokenization
en_fr_sentences = [mbert_tokenizer.tokenize(sentence)
                   for sentence in en_fr_ds['sentence']]  # (List[List[str]])

en_fr_translations = [mbert_tokenizer.tokenize(translation)
                      for translation in en_fr_ds['translation']] # (List[List[str]])

# %% [markdown]
# English - Persian

# %%
# English - Persian (Farsi)

# Removing the 'category' column
en_fa_ds = en_fa_ds.remove_columns(['category'])

# Removing list encapsulation
en_fa_ds = en_fa_ds.map(lambda example: {'targets': example['targets'][0]}, num_proc=4)

# Filtering out rows with the '\u200c' symbol and those where the length of either source or targets is less than a threshold
length_threshold = 30
filtered_en_fa_ds = en_fa_ds.filter(
    lambda example: '\u200c' not in example['targets']
                    and len(example['source']) >= length_threshold
                    and len(example['targets']) >= length_threshold
                    and 'Global Voices' not in example['source'], # Headlines. Very short and the 'Global Voices' part is never translated
    num_proc=4)

en_fa_ds = filtered_en_fa_ds.rename_column('source', 'sentence')\
                            .rename_column('targets', 'translation')\
                            .select(range(300))

# Tokenization
en_fa_sentences = [mbert_tokenizer.tokenize(sentence)
                   for sentence in en_fa_ds['sentence']]  # (List[List[str]])

en_fa_translations = [mbert_tokenizer.tokenize(translation)
                      for translation in en_fa_ds['translation']] # (List[List[str]])
# Out:
# Map (num_proc=4):   0%|          | 0/1621665 [00:00<?, ? examples/s]
# Filter (num_proc=4):   0%|          | 0/1621665 [00:00<?, ? examples/s]

# %% [markdown]
# ## Running the Program

# %% [markdown]
# English - French

# %%
BLANC_tune(en_fr_sentences[45], en_fr_translations[45], model_checkpoint, mbert_model, mbert_tokenizer, device=DEVICE)
# Out:
# {'train_runtime': 4.0061, 'train_samples_per_second': 37.443, 'train_steps_per_second': 5.242, 'train_loss': 0.3163124947320847, 'epoch': 3.0}
# -0.17647058823529413

# %%
print(en_fr_sentences[45])
print(en_fr_translations[45])
# Out:
# ['what', 'was', 'true', 'for', 'the', 'al', '##chem', '##ists', 'of', 'yo', '##re', 'remains', 'true', 'today', ':', 'gold', 'and', 'reason', 'are', 'often', 'difficult', 'to', 'rec', '##oncil', '##e', '.']
# ['ce', 'qui', 'etait', 'vrai', 'pour', 'les', 'al', '##chi', '##mist', '##es', 'd', '[UNK]', 'ant', '##an', 'reste', 'vrai', 'aujourd', '[UNK]', 'hui', ':', 'l', '[UNK]', 'or', 'et', 'la', 'raison', 'sont', 'parfois', 'difficile', '##s', 'a', 'con', '##cili', '##er', '.']

# %%
en_fr_scores = [BLANC_tune(sentences, translations, model_checkpoint, mbert_model, mbert_tokenizer, device=DEVICE)
                for sentences, translations in tqdm(zip(en_fr_sentences, en_fr_translations), total=len(en_fr_sentences))]
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# {'train_runtime': 1.6655, 'train_samples_per_second': 72.052, 'train_steps_per_second': 9.006, 'train_loss': 0.3297830581665039, 'epoch': 3.0}
# {'train_runtime': 2.8875, 'train_samples_per_second': 51.948, 'train_steps_per_second': 7.273, 'train_loss': 0.23243393216814315, 'epoch': 3.0}
# {'train_runtime': 2.7219, 'train_samples_per_second': 44.086, 'train_steps_per_second': 5.511, 'train_loss': 0.38886874516805015, 'epoch': 3.0}
# {'train_runtime': 4.9732, 'train_samples_per_second': 36.194, 'train_steps_per_second': 4.826, 'train_loss': 0.13696845372517905, 'epoch': 3.0}
# {'train_runtime': 2.4369, 'train_samples_per_second': 61.554, 'train_steps_per_second': 8.618, 'train_loss': 0.37855416252499535, 'epoch': 3.0}
# {'train_runtime': 3.2998, 'train_samples_per_second': 45.457, 'train_steps_per_second': 6.364, 'train_loss': 0.2629982857477097, 'epoch': 3.0}
# {'train_runtime': 3.4038, 'train_samples_per_second': 52.882, 'train_steps_per_second': 7.051, 'train_loss': 0.13006973266601562, 'epoch': 3.0}
# {'train_runtime': 3.3668, 'train_samples_per_second': 53.463, 'train_steps_per_second': 7.128, 'train_loss': 0.15721043944358826, 'epoch': 3.0}
# {'train_runtime': 3.6461, 'train_samples_per_second': 41.14, 'train_steps_per_second': 5.76, 'train_loss': 0.15257193928673154, 'epoch': 3.0}
# {'train_runtime': 1.4924, 'train_samples_per_second': 60.305, 'train_steps_per_second': 8.041, 'train_loss': 0.2608706553777059, 'epoch': 3.0}
# {'train_runtime': 2.4944, 'train_samples_per_second': 48.109, 'train_steps_per_second': 6.014, 'train_loss': 0.25800337791442873, 'epoch': 3.0}
# {'train_runtime': 3.315, 'train_samples_per_second': 45.249, 'train_steps_per_second': 6.335, 'train_loss': 0.14103950772966659, 'epoch': 3.0}
# {'train_runtime': 3.5822, 'train_samples_per_second': 41.874, 'train_steps_per_second': 5.862, 'train_loss': 0.1517201718829927, 'epoch': 3.0}
# {'train_runtime': 3.3715, 'train_samples_per_second': 62.288, 'train_steps_per_second': 8.008, 'train_loss': 0.3496161566840278, 'epoch': 3.0}
# {'train_runtime': 3.0829, 'train_samples_per_second': 48.655, 'train_steps_per_second': 6.812, 'train_loss': 0.18617497171674455, 'epoch': 3.0}
# {'train_runtime': 2.1822, 'train_samples_per_second': 54.99, 'train_steps_per_second': 6.874, 'train_loss': 0.14435259501139322, 'epoch': 3.0}
# {'train_runtime': 3.173, 'train_samples_per_second': 66.183, 'train_steps_per_second': 8.509, 'train_loss': 0.13200447294447157, 'epoch': 3.0}
# {'train_runtime': 4.2247, 'train_samples_per_second': 35.506, 'train_steps_per_second': 4.971, 'train_loss': 0.1221700736454555, 'epoch': 3.0}
# {'train_runtime': 2.1998, 'train_samples_per_second': 54.55, 'train_steps_per_second': 6.819, 'train_loss': 0.28120622634887693, 'epoch': 3.0}
# {'train_runtime': 3.0135, 'train_samples_per_second': 49.776, 'train_steps_per_second': 6.969, 'train_loss': 0.508998053414481, 'epoch': 3.0}
# {'train_runtime': 3.8644, 'train_samples_per_second': 46.578, 'train_steps_per_second': 6.21, 'train_loss': 0.1009168028831482, 'epoch': 3.0}
# {'train_runtime': 5.1608, 'train_samples_per_second': 29.065, 'train_steps_per_second': 4.069, 'train_loss': 0.09792013395400274, 'epoch': 3.0}
# {'train_runtime': 3.0872, 'train_samples_per_second': 48.587, 'train_steps_per_second': 6.802, 'train_loss': 0.0830408391498384, 'epoch': 3.0}
# {'train_runtime': 2.6229, 'train_samples_per_second': 68.627, 'train_steps_per_second': 9.15, 'train_loss': 0.34359018007914227, 'epoch': 3.0}
# {'train_runtime': 3.3955, 'train_samples_per_second': 35.341, 'train_steps_per_second': 4.418, 'train_loss': 0.2337140401204427, 'epoch': 3.0}
# {'train_runtime': 3.0106, 'train_samples_per_second': 39.859, 'train_steps_per_second': 4.982, 'train_loss': 0.15913912455240886, 'epoch': 3.0}
# {'train_runtime': 2.274, 'train_samples_per_second': 52.771, 'train_steps_per_second': 6.596, 'train_loss': 0.36640694936116536, 'epoch': 3.0}
# {'train_runtime': 3.6131, 'train_samples_per_second': 41.515, 'train_steps_per_second': 5.812, 'train_loss': 0.17961879003615605, 'epoch': 3.0}
# {'train_runtime': 3.5664, 'train_samples_per_second': 50.472, 'train_steps_per_second': 6.73, 'train_loss': 0.1577353278795878, 'epoch': 3.0}
# {'train_runtime': 3.7309, 'train_samples_per_second': 40.205, 'train_steps_per_second': 5.629, 'train_loss': 0.40583951132638113, 'epoch': 3.0}
# {'train_runtime': 4.4145, 'train_samples_per_second': 40.775, 'train_steps_per_second': 5.437, 'train_loss': 0.13978246847788492, 'epoch': 3.0}
# {'train_runtime': 3.6203, 'train_samples_per_second': 41.433, 'train_steps_per_second': 5.801, 'train_loss': 0.09859455199468703, 'epoch': 3.0}
# {'train_runtime': 3.0612, 'train_samples_per_second': 49.001, 'train_steps_per_second': 6.86, 'train_loss': 0.2067394710722424, 'epoch': 3.0}
# {'train_runtime': 4.2894, 'train_samples_per_second': 34.97, 'train_steps_per_second': 4.896, 'train_loss': 0.12320884068806966, 'epoch': 3.0}
# {'train_runtime': 3.1254, 'train_samples_per_second': 47.994, 'train_steps_per_second': 6.719, 'train_loss': 0.13681599072047643, 'epoch': 3.0}
# {'train_runtime': 2.7412, 'train_samples_per_second': 54.722, 'train_steps_per_second': 7.661, 'train_loss': 0.352205685206822, 'epoch': 3.0}
# {'train_runtime': 1.9443, 'train_samples_per_second': 61.719, 'train_steps_per_second': 7.715, 'train_loss': 0.23869938850402833, 'epoch': 3.0}
# {'train_runtime': 2.5927, 'train_samples_per_second': 46.283, 'train_steps_per_second': 5.785, 'train_loss': 0.3681095441182454, 'epoch': 3.0}
# {'train_runtime': 3.4881, 'train_samples_per_second': 43.003, 'train_steps_per_second': 6.02, 'train_loss': 0.1194645223163423, 'epoch': 3.0}
# {'train_runtime': 2.8039, 'train_samples_per_second': 42.798, 'train_steps_per_second': 5.35, 'train_loss': 0.14974409739176434, 'epoch': 3.0}
# {'train_runtime': 3.1312, 'train_samples_per_second': 57.486, 'train_steps_per_second': 7.665, 'train_loss': 0.21349281072616577, 'epoch': 3.0}
# {'train_runtime': 3.6229, 'train_samples_per_second': 41.403, 'train_steps_per_second': 5.796, 'train_loss': 0.12310580980210077, 'epoch': 3.0}
# {'train_runtime': 3.7414, 'train_samples_per_second': 40.092, 'train_steps_per_second': 5.613, 'train_loss': 0.15349067960466659, 'epoch': 3.0}
# {'train_runtime': 4.0718, 'train_samples_per_second': 44.206, 'train_steps_per_second': 5.894, 'train_loss': 0.1232551634311676, 'epoch': 3.0}
# {'train_runtime': 2.0668, 'train_samples_per_second': 58.06, 'train_steps_per_second': 7.257, 'train_loss': 0.34423163731892903, 'epoch': 3.0}
# {'train_runtime': 3.4966, 'train_samples_per_second': 42.899, 'train_steps_per_second': 6.006, 'train_loss': 0.3163124947320847, 'epoch': 3.0}
# Exception ignored in: <function _xla_gc_callback at 0x7b8af3c20670>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-2808177b7bcf> in <cell line: 1>()
# ----> 1 en_fr_scores = [BLANC_tune(sentences, translations, model_checkpoint, mbert_model, mbert_tokenizer, device=DEVICE)
#       2                 for sentences, translations in tqdm(zip(en_fr_sentences, en_fr_translations), total=len(en_fr_sentences))]
#
# <ipython-input-19-2808177b7bcf> in <listcomp>(.0)
# ----> 1 en_fr_scores = [BLANC_tune(sentences, translations, model_checkpoint, mbert_model, mbert_tokenizer, device=DEVICE)
#       2                 for sentences, translations in tqdm(zip(en_fr_sentences, en_fr_translations), total=len(en_fr_sentences))]
#
# <ipython-input-8-c3447b6226ce> in BLANC_tune(sentence, translation, model_checkpoint, model, tokenizer, p_mask, L_min, N, n_epochs, device)
#      20                 masked_translation[pos_to_mask] = tokenizer.mask_token_id
#      21             # Add translation with masked words to set_tune
# ---> 22             set_tune = set_tune.add_item({"input_ids": masked_translation, 'labels': translation_ids})
#      23             pos = pos[N_mask:]
#      24
#
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_dataset.py in wrapper(*args, **kwargs)
#     555         }
#     556         # apply actual function
# --> 557         out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     558         datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     559         # re-apply format to the output
#
# /usr/local/lib/python3.10/dist-packages/datasets/fingerprint.py in wrapper(*args, **kwargs)
#     479             # Call actual function
#     480
# --> 481             out = func(dataset, *args, **kwargs)
#     482
#     483             # Update fingerprint of in-place transforms + update in-place history of transforms
#
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_dataset.py in add_item(self, item, new_fingerprint)
#    5860             table,
#    5861             info=info,
# -> 5862             split=self.split,
#    5863             indices_table=indices_table,
#    5864             fingerprint=new_fingerprint,
#
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_dataset.py in split(self)
#     161         return self._info
#     162
# --> 163     @property
#     164     def split(self):
#     165         """[`~datasets.NamedSplit`] object corresponding to a named dataset split."""
#
# KeyboardInterrupt:

# %%
en_fr_scores

# %%
en_fr_data = {}
en_fr_data['BLANC_tune_en_fr_translation'] = en_fr_scores
add_results_to_json(en_fr_data)

# %% [markdown]
# English - Persian (Farsi)

# %%
BLANC_tune(en_fa_sentences[0], en_fa_translations[0], model_checkpoint, mbert_model, mbert_tokenizer, device=DEVICE)
# Out:
# {'train_runtime': 3.6589, 'train_samples_per_second': 40.996, 'train_steps_per_second': 5.739, 'train_loss': 0.13686458269755045, 'epoch': 3.0}
# -0.07692307692307693

# %%
en_fa_scores = [BLANC_tune(sentences, translations, model_checkpoint, mbert_model, mbert_tokenizer, device=DEVICE)
                for sentences, translations in tqdm(zip(en_fa_sentences, en_fa_translations), total=len(en_fa_sentences))]
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# {'train_runtime': 3.902, 'train_samples_per_second': 38.442, 'train_steps_per_second': 5.382, 'train_loss': 0.09289323148273286, 'epoch': 3.0}
# {'train_runtime': 3.8127, 'train_samples_per_second': 55.079, 'train_steps_per_second': 7.082, 'train_loss': 0.10461229748196071, 'epoch': 3.0}
# {'train_runtime': 2.4844, 'train_samples_per_second': 60.377, 'train_steps_per_second': 8.453, 'train_loss': 0.16667411440894717, 'epoch': 3.0}
# {'train_runtime': 3.6707, 'train_samples_per_second': 49.038, 'train_steps_per_second': 6.538, 'train_loss': 0.0751963456471761, 'epoch': 3.0}
# {'train_runtime': 3.508, 'train_samples_per_second': 51.312, 'train_steps_per_second': 6.842, 'train_loss': 0.08011201024055481, 'epoch': 3.0}
# {'train_runtime': 3.4084, 'train_samples_per_second': 52.811, 'train_steps_per_second': 7.041, 'train_loss': 0.11016147335370381, 'epoch': 3.0}
# {'train_runtime': 4.9219, 'train_samples_per_second': 36.571, 'train_steps_per_second': 4.876, 'train_loss': 0.1320984959602356, 'epoch': 3.0}
# {'train_runtime': 3.1548, 'train_samples_per_second': 57.056, 'train_steps_per_second': 7.608, 'train_loss': 0.2858853538831075, 'epoch': 3.0}
# {'train_runtime': 3.6479, 'train_samples_per_second': 49.343, 'train_steps_per_second': 6.579, 'train_loss': 0.07898563146591187, 'epoch': 3.0}
# {'train_runtime': 3.1997, 'train_samples_per_second': 56.256, 'train_steps_per_second': 7.501, 'train_loss': 0.1766800880432129, 'epoch': 3.0}
# {'train_runtime': 2.8036, 'train_samples_per_second': 53.502, 'train_steps_per_second': 7.49, 'train_loss': 0.09206367674328032, 'epoch': 3.0}
# {'train_runtime': 3.7496, 'train_samples_per_second': 40.004, 'train_steps_per_second': 5.601, 'train_loss': 0.08863382112412226, 'epoch': 3.0}
# {'train_runtime': 3.4816, 'train_samples_per_second': 68.935, 'train_steps_per_second': 8.617, 'train_loss': 0.1491547107696533, 'epoch': 3.0}
# {'train_runtime': 3.4491, 'train_samples_per_second': 52.187, 'train_steps_per_second': 6.958, 'train_loss': 0.28439952929814655, 'epoch': 3.0}
# {'train_runtime': 3.2037, 'train_samples_per_second': 65.548, 'train_steps_per_second': 8.428, 'train_loss': 0.2253026255854854, 'epoch': 3.0}
# {'train_runtime': 3.6984, 'train_samples_per_second': 40.558, 'train_steps_per_second': 5.678, 'train_loss': 0.12497241156441825, 'epoch': 3.0}
# {'train_runtime': 2.7068, 'train_samples_per_second': 55.416, 'train_steps_per_second': 7.758, 'train_loss': 0.09762838908604213, 'epoch': 3.0}
# {'train_runtime': 3.002, 'train_samples_per_second': 59.961, 'train_steps_per_second': 7.995, 'train_loss': 0.17112159729003906, 'epoch': 3.0}
# {'train_runtime': 2.5095, 'train_samples_per_second': 59.772, 'train_steps_per_second': 8.368, 'train_loss': 0.20552605674380348, 'epoch': 3.0}
# {'train_runtime': 3.5653, 'train_samples_per_second': 50.487, 'train_steps_per_second': 6.732, 'train_loss': 0.12151866157849629, 'epoch': 3.0}
# {'train_runtime': 3.0145, 'train_samples_per_second': 49.759, 'train_steps_per_second': 6.966, 'train_loss': 0.175409544081915, 'epoch': 3.0}
# {'train_runtime': 4.474, 'train_samples_per_second': 40.233, 'train_steps_per_second': 5.364, 'train_loss': 0.10339642564455669, 'epoch': 3.0}
# {'train_runtime': 3.2084, 'train_samples_per_second': 56.103, 'train_steps_per_second': 7.48, 'train_loss': 0.16252630949020386, 'epoch': 3.0}
# {'train_runtime': 4.3929, 'train_samples_per_second': 54.634, 'train_steps_per_second': 6.829, 'train_loss': 0.12634936968485513, 'epoch': 3.0}
# {'train_runtime': 5.2074, 'train_samples_per_second': 34.566, 'train_steps_per_second': 4.609, 'train_loss': 0.06849335630734761, 'epoch': 3.0}
# {'train_runtime': 2.6314, 'train_samples_per_second': 57.004, 'train_steps_per_second': 7.981, 'train_loss': 0.1996140025910877, 'epoch': 3.0}
# {'train_runtime': 2.759, 'train_samples_per_second': 54.367, 'train_steps_per_second': 7.611, 'train_loss': 0.14577567009698778, 'epoch': 3.0}
# {'train_runtime': 4.9475, 'train_samples_per_second': 36.382, 'train_steps_per_second': 4.851, 'train_loss': 0.25255576769510907, 'epoch': 3.0}
# {'train_runtime': 4.0417, 'train_samples_per_second': 44.536, 'train_steps_per_second': 5.938, 'train_loss': 0.12101743618647258, 'epoch': 3.0}
# {'train_runtime': 3.6348, 'train_samples_per_second': 49.521, 'train_steps_per_second': 6.603, 'train_loss': 0.08948159217834473, 'epoch': 3.0}
# {'train_runtime': 3.8431, 'train_samples_per_second': 62.45, 'train_steps_per_second': 7.806, 'train_loss': 0.16506284077962238, 'epoch': 3.0}
# {'train_runtime': 3.1251, 'train_samples_per_second': 67.198, 'train_steps_per_second': 8.64, 'train_loss': 0.14845664412887008, 'epoch': 3.0}
# {'train_runtime': 4.3683, 'train_samples_per_second': 34.338, 'train_steps_per_second': 4.807, 'train_loss': 0.14544216791788736, 'epoch': 3.0}
# {'train_runtime': 4.2726, 'train_samples_per_second': 42.129, 'train_steps_per_second': 5.617, 'train_loss': 0.13712317744890848, 'epoch': 3.0}
# {'train_runtime': 2.8012, 'train_samples_per_second': 64.259, 'train_steps_per_second': 8.568, 'train_loss': 0.2554807662963867, 'epoch': 3.0}
# {'train_runtime': 3.0474, 'train_samples_per_second': 49.223, 'train_steps_per_second': 6.891, 'train_loss': 0.1673031420934768, 'epoch': 3.0}
# {'train_runtime': 4.1325, 'train_samples_per_second': 65.335, 'train_steps_per_second': 8.711, 'train_loss': 0.13674835364023843, 'epoch': 3.0}
# {'train_runtime': 3.4745, 'train_samples_per_second': 43.171, 'train_steps_per_second': 6.044, 'train_loss': 0.25473447073073613, 'epoch': 3.0}
# {'train_runtime': 3.1722, 'train_samples_per_second': 56.744, 'train_steps_per_second': 7.566, 'train_loss': 0.18332505226135254, 'epoch': 3.0}
# {'train_runtime': 3.5399, 'train_samples_per_second': 50.849, 'train_steps_per_second': 6.78, 'train_loss': 0.1312843163808187, 'epoch': 3.0}
# {'train_runtime': 3.281, 'train_samples_per_second': 54.862, 'train_steps_per_second': 7.315, 'train_loss': 0.14466320474942526, 'epoch': 3.0}
# {'train_runtime': 4.3367, 'train_samples_per_second': 69.177, 'train_steps_per_second': 8.993, 'train_loss': 0.17868605638161683, 'epoch': 3.0}
# {'train_runtime': 3.4272, 'train_samples_per_second': 52.521, 'train_steps_per_second': 7.003, 'train_loss': 0.10809762279192607, 'epoch': 3.0}
# {'train_runtime': 3.5262, 'train_samples_per_second': 59.554, 'train_steps_per_second': 7.657, 'train_loss': 0.1860136455959744, 'epoch': 3.0}
# {'train_runtime': 3.4807, 'train_samples_per_second': 60.332, 'train_steps_per_second': 7.757, 'train_loss': 0.17011359885886865, 'epoch': 3.0}
# {'train_runtime': 4.0204, 'train_samples_per_second': 44.772, 'train_steps_per_second': 5.97, 'train_loss': 0.09263413151105244, 'epoch': 3.0}
# {'train_runtime': 3.4679, 'train_samples_per_second': 60.556, 'train_steps_per_second': 7.786, 'train_loss': 0.09821203902915672, 'epoch': 3.0}
# {'train_runtime': 3.4373, 'train_samples_per_second': 61.094, 'train_steps_per_second': 7.855, 'train_loss': 0.11602766425521285, 'epoch': 3.0}
# {'train_runtime': 2.8128, 'train_samples_per_second': 53.328, 'train_steps_per_second': 7.466, 'train_loss': 0.2213878631591797, 'epoch': 3.0}
# {'train_runtime': 4.0639, 'train_samples_per_second': 44.292, 'train_steps_per_second': 5.906, 'train_loss': 0.10328799486160278, 'epoch': 3.0}
# {'train_runtime': 2.8372, 'train_samples_per_second': 63.444, 'train_steps_per_second': 8.459, 'train_loss': 0.29952683051427204, 'epoch': 3.0}
# {'train_runtime': 4.0841, 'train_samples_per_second': 44.073, 'train_steps_per_second': 5.876, 'train_loss': 0.0885418951511383, 'epoch': 3.0}
# {'train_runtime': 1.5575, 'train_samples_per_second': 57.784, 'train_steps_per_second': 7.704, 'train_loss': 0.3267657558123271, 'epoch': 3.0}
# {'train_runtime': 4.6561, 'train_samples_per_second': 51.545, 'train_steps_per_second': 6.443, 'train_loss': 0.09016416867574056, 'epoch': 3.0}
# {'train_runtime': 4.5041, 'train_samples_per_second': 39.964, 'train_steps_per_second': 5.329, 'train_loss': 0.10524329543113708, 'epoch': 3.0}
# {'train_runtime': 4.1049, 'train_samples_per_second': 51.159, 'train_steps_per_second': 6.578, 'train_loss': 0.08008322892365632, 'epoch': 3.0}
# {'train_runtime': 2.8281, 'train_samples_per_second': 53.039, 'train_steps_per_second': 7.426, 'train_loss': 0.13899089041210355, 'epoch': 3.0}
# {'train_runtime': 3.5014, 'train_samples_per_second': 42.839, 'train_steps_per_second': 5.998, 'train_loss': 0.10594414529346284, 'epoch': 3.0}
# {'train_runtime': 3.6395, 'train_samples_per_second': 57.701, 'train_steps_per_second': 7.419, 'train_loss': 0.12174041182906539, 'epoch': 3.0}
# {'train_runtime': 4.0493, 'train_samples_per_second': 44.452, 'train_steps_per_second': 5.927, 'train_loss': 0.09895817438761394, 'epoch': 3.0}
# {'train_runtime': 3.0798, 'train_samples_per_second': 58.446, 'train_steps_per_second': 7.793, 'train_loss': 0.1920068860054016, 'epoch': 3.0}
# {'train_runtime': 3.0077, 'train_samples_per_second': 59.846, 'train_steps_per_second': 7.979, 'train_loss': 0.1497820814450582, 'epoch': 3.0}
# {'train_runtime': 3.135, 'train_samples_per_second': 57.417, 'train_steps_per_second': 7.656, 'train_loss': 0.10754997531572978, 'epoch': 3.0}
# {'train_runtime': 3.4467, 'train_samples_per_second': 52.224, 'train_steps_per_second': 6.963, 'train_loss': 0.07049765189488728, 'epoch': 3.0}
# {'train_runtime': 4.8102, 'train_samples_per_second': 43.657, 'train_steps_per_second': 5.613, 'train_loss': 0.0801851749420166, 'epoch': 3.0}
# {'train_runtime': 3.4909, 'train_samples_per_second': 42.969, 'train_steps_per_second': 6.016, 'train_loss': 0.12579680624462308, 'epoch': 3.0}
# {'train_runtime': 3.048, 'train_samples_per_second': 59.056, 'train_steps_per_second': 7.874, 'train_loss': 0.14963566263516745, 'epoch': 3.0}
# {'train_runtime': 3.1207, 'train_samples_per_second': 57.68, 'train_steps_per_second': 7.691, 'train_loss': 0.2046449383099874, 'epoch': 3.0}
# {'train_runtime': 5.2065, 'train_samples_per_second': 69.144, 'train_steps_per_second': 8.643, 'train_loss': 0.1485211478339301, 'epoch': 3.0}
# {'train_runtime': 5.9238, 'train_samples_per_second': 35.45, 'train_steps_per_second': 4.558, 'train_loss': 0.06895803963696515, 'epoch': 3.0}
# {'train_runtime': 3.7643, 'train_samples_per_second': 39.848, 'train_steps_per_second': 5.579, 'train_loss': 0.16737566675458634, 'epoch': 3.0}
# {'train_runtime': 3.4749, 'train_samples_per_second': 51.799, 'train_steps_per_second': 6.907, 'train_loss': 0.1196747620900472, 'epoch': 3.0}
# {'train_runtime': 3.5518, 'train_samples_per_second': 50.679, 'train_steps_per_second': 6.757, 'train_loss': 0.09338106711705525, 'epoch': 3.0}
# {'train_runtime': 3.2036, 'train_samples_per_second': 56.186, 'train_steps_per_second': 7.492, 'train_loss': 0.11818564931551616, 'epoch': 3.0}
# {'train_runtime': 4.0362, 'train_samples_per_second': 44.596, 'train_steps_per_second': 5.946, 'train_loss': 0.13010028998057047, 'epoch': 3.0}
# {'train_runtime': 3.5043, 'train_samples_per_second': 51.366, 'train_steps_per_second': 6.849, 'train_loss': 0.11994340022404988, 'epoch': 3.0}
# {'train_runtime': 4.7554, 'train_samples_per_second': 44.16, 'train_steps_per_second': 5.678, 'train_loss': 0.11971200837029351, 'epoch': 3.0}
# {'train_runtime': 4.1256, 'train_samples_per_second': 43.63, 'train_steps_per_second': 5.817, 'train_loss': 0.10542742411295573, 'epoch': 3.0}
# {'train_runtime': 2.6348, 'train_samples_per_second': 56.931, 'train_steps_per_second': 7.97, 'train_loss': 1.6130594526018416, 'epoch': 3.0}
# {'train_runtime': 4.1019, 'train_samples_per_second': 51.195, 'train_steps_per_second': 6.582, 'train_loss': 0.0994730967062491, 'epoch': 3.0}
# {'train_runtime': 4.105, 'train_samples_per_second': 43.848, 'train_steps_per_second': 5.846, 'train_loss': 0.0762262890736262, 'epoch': 3.0}
# {'train_runtime': 2.844, 'train_samples_per_second': 63.29, 'train_steps_per_second': 8.439, 'train_loss': 0.1469996968905131, 'epoch': 3.0}
# {'train_runtime': 3.4162, 'train_samples_per_second': 52.691, 'train_steps_per_second': 7.025, 'train_loss': 0.1784504453341166, 'epoch': 3.0}
# {'train_runtime': 2.467, 'train_samples_per_second': 60.803, 'train_steps_per_second': 8.512, 'train_loss': 0.27429950804937453, 'epoch': 3.0}
# {'train_runtime': 3.2043, 'train_samples_per_second': 56.175, 'train_steps_per_second': 7.49, 'train_loss': 0.1676581104596456, 'epoch': 3.0}
# {'train_runtime': 3.6783, 'train_samples_per_second': 40.78, 'train_steps_per_second': 5.709, 'train_loss': 0.09703390938895089, 'epoch': 3.0}
# {'train_runtime': 2.8345, 'train_samples_per_second': 42.336, 'train_steps_per_second': 5.292, 'train_loss': 0.13461682001749675, 'epoch': 3.0}
# {'train_runtime': 1.8092, 'train_samples_per_second': 66.328, 'train_steps_per_second': 8.291, 'train_loss': 0.16781926155090332, 'epoch': 3.0}
# {'train_runtime': 2.7143, 'train_samples_per_second': 55.263, 'train_steps_per_second': 7.737, 'train_loss': 0.10434307370867048, 'epoch': 3.0}
# {'train_runtime': 2.8382, 'train_samples_per_second': 63.42, 'train_steps_per_second': 8.456, 'train_loss': 0.15368827184041342, 'epoch': 3.0}
# {'train_runtime': 3.1736, 'train_samples_per_second': 56.718, 'train_steps_per_second': 7.562, 'train_loss': 0.09873537222544353, 'epoch': 3.0}
# {'train_runtime': 2.5669, 'train_samples_per_second': 58.437, 'train_steps_per_second': 8.181, 'train_loss': 0.11635581652323405, 'epoch': 3.0}
# {'train_runtime': 2.4492, 'train_samples_per_second': 61.244, 'train_steps_per_second': 8.574, 'train_loss': 0.16930936631702243, 'epoch': 3.0}
# {'train_runtime': 2.6155, 'train_samples_per_second': 57.35, 'train_steps_per_second': 8.029, 'train_loss': 0.26078594298589797, 'epoch': 3.0}
# {'train_runtime': 4.0487, 'train_samples_per_second': 51.868, 'train_steps_per_second': 6.669, 'train_loss': 0.20088315893102576, 'epoch': 3.0}
# {'train_runtime': 4.0339, 'train_samples_per_second': 52.059, 'train_steps_per_second': 6.693, 'train_loss': 0.3604946489687319, 'epoch': 3.0}
# {'train_runtime': 3.1691, 'train_samples_per_second': 47.331, 'train_steps_per_second': 6.626, 'train_loss': 0.13497860091073172, 'epoch': 3.0}
# {'train_runtime': 3.691, 'train_samples_per_second': 56.895, 'train_steps_per_second': 7.315, 'train_loss': 0.20314435605649594, 'epoch': 3.0}
# {'train_runtime': 3.6668, 'train_samples_per_second': 49.089, 'train_steps_per_second': 6.545, 'train_loss': 0.21740508079528809, 'epoch': 3.0}
# {'train_runtime': 3.5581, 'train_samples_per_second': 50.589, 'train_steps_per_second': 6.745, 'train_loss': 0.1694676081339518, 'epoch': 3.0}
# {'train_runtime': 3.4982, 'train_samples_per_second': 42.879, 'train_steps_per_second': 6.003, 'train_loss': 0.18227124214172363, 'epoch': 3.0}
# {'train_runtime': 2.7671, 'train_samples_per_second': 54.209, 'train_steps_per_second': 7.589, 'train_loss': 0.2396011125473749, 'epoch': 3.0}
# {'train_runtime': 3.1015, 'train_samples_per_second': 48.363, 'train_steps_per_second': 6.771, 'train_loss': 0.1256647337050665, 'epoch': 3.0}
# {'train_runtime': 5.0249, 'train_samples_per_second': 35.822, 'train_steps_per_second': 4.776, 'train_loss': 0.09789268175760905, 'epoch': 3.0}
# {'train_runtime': 4.4014, 'train_samples_per_second': 34.08, 'train_steps_per_second': 4.771, 'train_loss': 0.10472400983174641, 'epoch': 3.0}
# {'train_runtime': 3.6124, 'train_samples_per_second': 49.829, 'train_steps_per_second': 6.644, 'train_loss': 0.10952956477801006, 'epoch': 3.0}
# {'train_runtime': 4.133, 'train_samples_per_second': 43.551, 'train_steps_per_second': 5.807, 'train_loss': 0.1494120458761851, 'epoch': 3.0}
# {'train_runtime': 3.6627, 'train_samples_per_second': 49.145, 'train_steps_per_second': 6.553, 'train_loss': 0.15026046832402548, 'epoch': 3.0}
# {'train_runtime': 3.9923, 'train_samples_per_second': 45.087, 'train_steps_per_second': 6.012, 'train_loss': 0.12960165739059448, 'epoch': 3.0}
# {'train_runtime': 3.4572, 'train_samples_per_second': 60.743, 'train_steps_per_second': 7.81, 'train_loss': 0.12953881864194516, 'epoch': 3.0}
# {'train_runtime': 5.0677, 'train_samples_per_second': 35.519, 'train_steps_per_second': 4.736, 'train_loss': 0.1435247560342153, 'epoch': 3.0}
# {'train_runtime': 3.6114, 'train_samples_per_second': 41.535, 'train_steps_per_second': 5.815, 'train_loss': 0.18728157452174596, 'epoch': 3.0}
# {'train_runtime': 3.8957, 'train_samples_per_second': 61.606, 'train_steps_per_second': 7.701, 'train_loss': 0.2466594696044922, 'epoch': 3.0}
# {'train_runtime': 2.9375, 'train_samples_per_second': 40.851, 'train_steps_per_second': 5.106, 'train_loss': 0.09907167752583822, 'epoch': 3.0}
# {'train_runtime': 3.4828, 'train_samples_per_second': 43.069, 'train_steps_per_second': 6.03, 'train_loss': 0.14123221806117467, 'epoch': 3.0}
# {'train_runtime': 3.8732, 'train_samples_per_second': 38.728, 'train_steps_per_second': 5.422, 'train_loss': 0.10771312032427106, 'epoch': 3.0}
# {'train_runtime': 3.8397, 'train_samples_per_second': 39.066, 'train_steps_per_second': 5.469, 'train_loss': 0.11221920876275926, 'epoch': 3.0}
# {'train_runtime': 2.6958, 'train_samples_per_second': 55.642, 'train_steps_per_second': 7.79, 'train_loss': 0.23821456091744558, 'epoch': 3.0}
# {'train_runtime': 3.5471, 'train_samples_per_second': 42.288, 'train_steps_per_second': 5.92, 'train_loss': 0.1656732445671445, 'epoch': 3.0}
# {'train_runtime': 4.1493, 'train_samples_per_second': 43.38, 'train_steps_per_second': 5.784, 'train_loss': 0.16765604416529337, 'epoch': 3.0}
# {'train_runtime': 3.7004, 'train_samples_per_second': 56.751, 'train_steps_per_second': 7.297, 'train_loss': 0.11468588864361798, 'epoch': 3.0}
# {'train_runtime': 3.893, 'train_samples_per_second': 53.943, 'train_steps_per_second': 6.936, 'train_loss': 0.1697116427951389, 'epoch': 3.0}
# {'train_runtime': 5.1154, 'train_samples_per_second': 46.918, 'train_steps_per_second': 5.865, 'train_loss': 0.07160441875457764, 'epoch': 3.0}
# {'train_runtime': 3.4191, 'train_samples_per_second': 52.645, 'train_steps_per_second': 7.019, 'train_loss': 0.23913904031117758, 'epoch': 3.0}
# {'train_runtime': 3.479, 'train_samples_per_second': 43.116, 'train_steps_per_second': 6.036, 'train_loss': 0.09649808066231864, 'epoch': 3.0}
# {'train_runtime': 5.2759, 'train_samples_per_second': 34.117, 'train_steps_per_second': 4.549, 'train_loss': 0.1176009476184845, 'epoch': 3.0}
# {'train_runtime': 3.4647, 'train_samples_per_second': 69.27, 'train_steps_per_second': 8.659, 'train_loss': 0.27540918986002605, 'epoch': 3.0}
# {'train_runtime': 3.1118, 'train_samples_per_second': 48.204, 'train_steps_per_second': 6.749, 'train_loss': 0.16009522619701566, 'epoch': 3.0}
# {'train_runtime': 3.5747, 'train_samples_per_second': 50.354, 'train_steps_per_second': 6.714, 'train_loss': 0.09204806884129842, 'epoch': 3.0}
# {'train_runtime': 3.9229, 'train_samples_per_second': 61.179, 'train_steps_per_second': 7.647, 'train_loss': 0.14934253692626953, 'epoch': 3.0}
# {'train_runtime': 2.9421, 'train_samples_per_second': 40.787, 'train_steps_per_second': 5.098, 'train_loss': 0.16350638071695964, 'epoch': 3.0}
# {'train_runtime': 4.1584, 'train_samples_per_second': 43.286, 'train_steps_per_second': 5.772, 'train_loss': 0.11089310050010681, 'epoch': 3.0}
# {'train_runtime': 4.3593, 'train_samples_per_second': 41.291, 'train_steps_per_second': 5.506, 'train_loss': 0.15218977133433023, 'epoch': 3.0}
# {'train_runtime': 3.5683, 'train_samples_per_second': 50.444, 'train_steps_per_second': 6.726, 'train_loss': 0.08692411581675212, 'epoch': 3.0}
# {'train_runtime': 3.9108, 'train_samples_per_second': 53.697, 'train_steps_per_second': 6.904, 'train_loss': 0.12156124468202945, 'epoch': 3.0}
# {'train_runtime': 3.3278, 'train_samples_per_second': 63.105, 'train_steps_per_second': 8.113, 'train_loss': 0.12483051088121203, 'epoch': 3.0}
# {'train_runtime': 4.1368, 'train_samples_per_second': 43.512, 'train_steps_per_second': 5.802, 'train_loss': 0.08697752157847087, 'epoch': 3.0}
# {'train_runtime': 2.7157, 'train_samples_per_second': 55.233, 'train_steps_per_second': 7.733, 'train_loss': 0.1139426799047561, 'epoch': 3.0}
# {'train_runtime': 3.5919, 'train_samples_per_second': 50.112, 'train_steps_per_second': 6.682, 'train_loss': 0.11975270509719849, 'epoch': 3.0}
# {'train_runtime': 3.4362, 'train_samples_per_second': 61.115, 'train_steps_per_second': 7.858, 'train_loss': 0.21581296567563657, 'epoch': 3.0}
# {'train_runtime': 4.1298, 'train_samples_per_second': 43.586, 'train_steps_per_second': 5.811, 'train_loss': 0.11378270387649536, 'epoch': 3.0}
# {'train_runtime': 3.6419, 'train_samples_per_second': 49.424, 'train_steps_per_second': 6.59, 'train_loss': 0.10608215133349101, 'epoch': 3.0}
# {'train_runtime': 3.4644, 'train_samples_per_second': 69.275, 'train_steps_per_second': 8.659, 'train_loss': 0.2828647613525391, 'epoch': 3.0}
# {'train_runtime': 4.5994, 'train_samples_per_second': 32.613, 'train_steps_per_second': 4.566, 'train_loss': 0.1361208302634103, 'epoch': 3.0}
# {'train_runtime': 4.9628, 'train_samples_per_second': 36.27, 'train_steps_per_second': 4.836, 'train_loss': 0.09947535395622253, 'epoch': 3.0}
# {'train_runtime': 3.4412, 'train_samples_per_second': 34.872, 'train_steps_per_second': 4.359, 'train_loss': 0.21814044316609701, 'epoch': 3.0}
# {'train_runtime': 5.045, 'train_samples_per_second': 35.679, 'train_steps_per_second': 4.757, 'train_loss': 0.14985230565071106, 'epoch': 3.0}
# {'train_runtime': 3.8956, 'train_samples_per_second': 53.907, 'train_steps_per_second': 6.931, 'train_loss': 0.09383193651835124, 'epoch': 3.0}
# {'train_runtime': 3.096, 'train_samples_per_second': 48.45, 'train_steps_per_second': 6.783, 'train_loss': 0.1876761686234247, 'epoch': 3.0}
# {'train_runtime': 3.4925, 'train_samples_per_second': 60.129, 'train_steps_per_second': 7.731, 'train_loss': 0.11938407686021593, 'epoch': 3.0}
# {'train_runtime': 3.589, 'train_samples_per_second': 50.153, 'train_steps_per_second': 6.687, 'train_loss': 0.31804168224334717, 'epoch': 3.0}
# {'train_runtime': 3.4267, 'train_samples_per_second': 61.283, 'train_steps_per_second': 7.879, 'train_loss': 0.19113651911417642, 'epoch': 3.0}
# {'train_runtime': 1.6062, 'train_samples_per_second': 56.033, 'train_steps_per_second': 7.471, 'train_loss': 0.15025626619656882, 'epoch': 3.0}
# {'train_runtime': 3.0711, 'train_samples_per_second': 48.843, 'train_steps_per_second': 6.838, 'train_loss': 0.1869211651030041, 'epoch': 3.0}
# {'train_runtime': 4.195, 'train_samples_per_second': 42.908, 'train_steps_per_second': 5.721, 'train_loss': 0.12728513280550638, 'epoch': 3.0}
# {'train_runtime': 3.549, 'train_samples_per_second': 50.718, 'train_steps_per_second': 6.762, 'train_loss': 0.13289296627044678, 'epoch': 3.0}
# {'train_runtime': 3.544, 'train_samples_per_second': 42.325, 'train_steps_per_second': 5.925, 'train_loss': 0.10289842741830009, 'epoch': 3.0}
# {'train_runtime': 4.0852, 'train_samples_per_second': 44.061, 'train_steps_per_second': 5.875, 'train_loss': 0.10080507397651672, 'epoch': 3.0}
# {'train_runtime': 3.1996, 'train_samples_per_second': 56.256, 'train_steps_per_second': 7.501, 'train_loss': 0.2850813865661621, 'epoch': 3.0}
# {'train_runtime': 2.2796, 'train_samples_per_second': 52.64, 'train_steps_per_second': 6.58, 'train_loss': 0.1784566879272461, 'epoch': 3.0}
# {'train_runtime': 3.4287, 'train_samples_per_second': 43.748, 'train_steps_per_second': 6.125, 'train_loss': 0.15620507512773787, 'epoch': 3.0}
# {'train_runtime': 3.991, 'train_samples_per_second': 52.619, 'train_steps_per_second': 6.765, 'train_loss': 0.160308873211896, 'epoch': 3.0}
# {'train_runtime': 3.5331, 'train_samples_per_second': 50.946, 'train_steps_per_second': 6.793, 'train_loss': 0.16144537925720215, 'epoch': 3.0}
# {'train_runtime': 3.4554, 'train_samples_per_second': 60.775, 'train_steps_per_second': 7.814, 'train_loss': 0.13805777055245858, 'epoch': 3.0}
# {'train_runtime': 2.868, 'train_samples_per_second': 62.762, 'train_steps_per_second': 8.368, 'train_loss': 0.2054595947265625, 'epoch': 3.0}
# {'train_runtime': 3.6485, 'train_samples_per_second': 41.113, 'train_steps_per_second': 5.756, 'train_loss': 0.14248934246244885, 'epoch': 3.0}
# {'train_runtime': 4.3626, 'train_samples_per_second': 34.383, 'train_steps_per_second': 4.814, 'train_loss': 0.11925641695658366, 'epoch': 3.0}
# {'train_runtime': 3.4709, 'train_samples_per_second': 60.503, 'train_steps_per_second': 7.779, 'train_loss': 0.12793140058164243, 'epoch': 3.0}
# {'train_runtime': 2.0459, 'train_samples_per_second': 58.654, 'train_steps_per_second': 7.332, 'train_loss': 0.187590487798055, 'epoch': 3.0}
# {'train_runtime': 4.3813, 'train_samples_per_second': 41.083, 'train_steps_per_second': 5.478, 'train_loss': 0.13952828447024027, 'epoch': 3.0}
# {'train_runtime': 4.3523, 'train_samples_per_second': 34.465, 'train_steps_per_second': 4.825, 'train_loss': 0.1567440600622268, 'epoch': 3.0}
# {'train_runtime': 3.403, 'train_samples_per_second': 52.894, 'train_steps_per_second': 7.053, 'train_loss': 0.16845770676930746, 'epoch': 3.0}
# {'train_runtime': 3.9786, 'train_samples_per_second': 45.242, 'train_steps_per_second': 6.032, 'train_loss': 0.13591662049293518, 'epoch': 3.0}
# {'train_runtime': 4.6569, 'train_samples_per_second': 45.094, 'train_steps_per_second': 5.798, 'train_loss': 0.11240999786942094, 'epoch': 3.0}
# {'train_runtime': 3.1246, 'train_samples_per_second': 48.006, 'train_steps_per_second': 6.721, 'train_loss': 0.1392505850110735, 'epoch': 3.0}
# {'train_runtime': 4.0899, 'train_samples_per_second': 44.011, 'train_steps_per_second': 5.868, 'train_loss': 0.10034401218096416, 'epoch': 3.0}
# {'train_runtime': 4.9151, 'train_samples_per_second': 36.622, 'train_steps_per_second': 4.883, 'train_loss': 0.08215820789337158, 'epoch': 3.0}
# {'train_runtime': 3.6022, 'train_samples_per_second': 49.969, 'train_steps_per_second': 6.663, 'train_loss': 0.07548881073792775, 'epoch': 3.0}
# {'train_runtime': 4.3381, 'train_samples_per_second': 34.578, 'train_steps_per_second': 4.841, 'train_loss': 0.11561276799156553, 'epoch': 3.0}
# {'train_runtime': 3.8356, 'train_samples_per_second': 39.108, 'train_steps_per_second': 5.475, 'train_loss': 0.20986704599289668, 'epoch': 3.0}
# {'train_runtime': 3.4932, 'train_samples_per_second': 42.941, 'train_steps_per_second': 6.012, 'train_loss': 0.11660741624378022, 'epoch': 3.0}
# {'train_runtime': 4.4302, 'train_samples_per_second': 33.859, 'train_steps_per_second': 4.74, 'train_loss': 0.09099892207554408, 'epoch': 3.0}
# {'train_runtime': 3.1528, 'train_samples_per_second': 57.093, 'train_steps_per_second': 7.612, 'train_loss': 0.16968756914138794, 'epoch': 3.0}
# {'train_runtime': 3.1988, 'train_samples_per_second': 65.65, 'train_steps_per_second': 8.441, 'train_loss': 0.14854120325159142, 'epoch': 3.0}
# {'train_runtime': 3.6551, 'train_samples_per_second': 57.455, 'train_steps_per_second': 7.387, 'train_loss': 0.10569180382622613, 'epoch': 3.0}
# {'train_runtime': 3.7846, 'train_samples_per_second': 63.415, 'train_steps_per_second': 7.927, 'train_loss': 0.15325133005777994, 'epoch': 3.0}
# {'train_runtime': 5.0775, 'train_samples_per_second': 35.451, 'train_steps_per_second': 4.727, 'train_loss': 0.11135404308636983, 'epoch': 3.0}
# {'train_runtime': 3.2638, 'train_samples_per_second': 55.15, 'train_steps_per_second': 7.353, 'train_loss': 0.3683512608210246, 'epoch': 3.0}
# {'train_runtime': 3.4433, 'train_samples_per_second': 60.989, 'train_steps_per_second': 7.841, 'train_loss': 0.1628372934129503, 'epoch': 3.0}
# {'train_runtime': 4.058, 'train_samples_per_second': 44.356, 'train_steps_per_second': 5.914, 'train_loss': 0.0883144239584605, 'epoch': 3.0}
# {'train_runtime': 3.9587, 'train_samples_per_second': 53.047, 'train_steps_per_second': 6.82, 'train_loss': 0.2144012804384585, 'epoch': 3.0}
# {'train_runtime': 3.9973, 'train_samples_per_second': 45.03, 'train_steps_per_second': 6.004, 'train_loss': 0.09117879470189412, 'epoch': 3.0}
# {'train_runtime': 3.4388, 'train_samples_per_second': 52.344, 'train_steps_per_second': 6.979, 'train_loss': 0.13424640893936157, 'epoch': 3.0}
# {'train_runtime': 1.9783, 'train_samples_per_second': 60.657, 'train_steps_per_second': 7.582, 'train_loss': 0.18279147148132324, 'epoch': 3.0}
# {'train_runtime': 3.6048, 'train_samples_per_second': 49.934, 'train_steps_per_second': 6.658, 'train_loss': 0.12417442599932353, 'epoch': 3.0}
# {'train_runtime': 3.2142, 'train_samples_per_second': 56.002, 'train_steps_per_second': 7.467, 'train_loss': 0.18713239828745523, 'epoch': 3.0}
# {'train_runtime': 3.4691, 'train_samples_per_second': 43.239, 'train_steps_per_second': 6.053, 'train_loss': 0.10667258217221215, 'epoch': 3.0}
# {'train_runtime': 4.1815, 'train_samples_per_second': 35.872, 'train_steps_per_second': 5.022, 'train_loss': 0.0862474384761992, 'epoch': 3.0}
# {'train_runtime': 4.1304, 'train_samples_per_second': 50.842, 'train_steps_per_second': 6.537, 'train_loss': 0.12388902240329319, 'epoch': 3.0}
# {'train_runtime': 2.2031, 'train_samples_per_second': 54.469, 'train_steps_per_second': 6.809, 'train_loss': 0.15754912694295248, 'epoch': 3.0}
# {'train_runtime': 1.8802, 'train_samples_per_second': 63.822, 'train_steps_per_second': 7.978, 'train_loss': 0.1814368724822998, 'epoch': 3.0}
# {'train_runtime': 3.6307, 'train_samples_per_second': 49.577, 'train_steps_per_second': 6.61, 'train_loss': 0.11870065331459045, 'epoch': 3.0}
# {'train_runtime': 3.5738, 'train_samples_per_second': 41.972, 'train_steps_per_second': 5.876, 'train_loss': 0.11350900786263603, 'epoch': 3.0}
# {'train_runtime': 5.8883, 'train_samples_per_second': 30.569, 'train_steps_per_second': 4.076, 'train_loss': 0.08571239312489827, 'epoch': 3.0}
# {'train_runtime': 3.402, 'train_samples_per_second': 61.728, 'train_steps_per_second': 7.936, 'train_loss': 0.21787811208654334, 'epoch': 3.0}
# {'train_runtime': 2.4788, 'train_samples_per_second': 60.514, 'train_steps_per_second': 8.472, 'train_loss': 0.125015690213158, 'epoch': 3.0}
# {'train_runtime': 3.6421, 'train_samples_per_second': 41.185, 'train_steps_per_second': 5.766, 'train_loss': 0.11983433223906018, 'epoch': 3.0}
# {'train_runtime': 3.5931, 'train_samples_per_second': 50.096, 'train_steps_per_second': 6.68, 'train_loss': 0.11201918125152588, 'epoch': 3.0}
# {'train_runtime': 2.1389, 'train_samples_per_second': 56.103, 'train_steps_per_second': 7.013, 'train_loss': 0.7595630009969075, 'epoch': 3.0}
# {'train_runtime': 3.53, 'train_samples_per_second': 50.991, 'train_steps_per_second': 6.799, 'train_loss': 0.12391345699628194, 'epoch': 3.0}
# {'train_runtime': 1.496, 'train_samples_per_second': 60.159, 'train_steps_per_second': 8.021, 'train_loss': 0.18631056944529215, 'epoch': 3.0}
# {'train_runtime': 2.3214, 'train_samples_per_second': 51.693, 'train_steps_per_second': 6.462, 'train_loss': 0.11761981646219889, 'epoch': 3.0}
# {'train_runtime': 2.9243, 'train_samples_per_second': 61.552, 'train_steps_per_second': 8.207, 'train_loss': 0.20402991771697998, 'epoch': 3.0}
# {'train_runtime': 3.9575, 'train_samples_per_second': 53.064, 'train_steps_per_second': 6.822, 'train_loss': 0.15244406240957756, 'epoch': 3.0}
# {'train_runtime': 4.7234, 'train_samples_per_second': 44.46, 'train_steps_per_second': 5.716, 'train_loss': 0.30498939090304905, 'epoch': 3.0}
# {'train_runtime': 3.5243, 'train_samples_per_second': 59.587, 'train_steps_per_second': 7.661, 'train_loss': 0.16186744195443611, 'epoch': 3.0}
# {'train_runtime': 2.9999, 'train_samples_per_second': 50.002, 'train_steps_per_second': 7.0, 'train_loss': 0.1411783014025007, 'epoch': 3.0}
# {'train_runtime': 3.3989, 'train_samples_per_second': 70.611, 'train_steps_per_second': 8.826, 'train_loss': 0.22770716349283854, 'epoch': 3.0}
# {'train_runtime': 2.5677, 'train_samples_per_second': 58.418, 'train_steps_per_second': 8.179, 'train_loss': 0.23958903267270043, 'epoch': 3.0}
# {'train_runtime': 4.3109, 'train_samples_per_second': 41.755, 'train_steps_per_second': 5.567, 'train_loss': 0.06696601212024689, 'epoch': 3.0}
# {'train_runtime': 3.0442, 'train_samples_per_second': 59.129, 'train_steps_per_second': 7.884, 'train_loss': 0.11559794346491496, 'epoch': 3.0}
# {'train_runtime': 2.845, 'train_samples_per_second': 63.269, 'train_steps_per_second': 8.436, 'train_loss': 0.11123517155647278, 'epoch': 3.0}
# {'train_runtime': 4.894, 'train_samples_per_second': 36.78, 'train_steps_per_second': 4.904, 'train_loss': 0.11648953954378764, 'epoch': 3.0}
# {'train_runtime': 2.756, 'train_samples_per_second': 43.542, 'train_steps_per_second': 5.443, 'train_loss': 0.25132516225179036, 'epoch': 3.0}
# {'train_runtime': 2.3547, 'train_samples_per_second': 63.703, 'train_steps_per_second': 8.918, 'train_loss': 0.3221156710670108, 'epoch': 3.0}
# {'train_runtime': 3.5708, 'train_samples_per_second': 50.409, 'train_steps_per_second': 6.721, 'train_loss': 0.0946560005346934, 'epoch': 3.0}
# {'train_runtime': 4.1525, 'train_samples_per_second': 43.347, 'train_steps_per_second': 5.78, 'train_loss': 0.08491974075635274, 'epoch': 3.0}
# {'train_runtime': 3.1831, 'train_samples_per_second': 56.548, 'train_steps_per_second': 7.54, 'train_loss': 0.10652770598729451, 'epoch': 3.0}
# {'train_runtime': 4.496, 'train_samples_per_second': 40.036, 'train_steps_per_second': 5.338, 'train_loss': 0.11753565073013306, 'epoch': 3.0}
# {'train_runtime': 5.0114, 'train_samples_per_second': 29.932, 'train_steps_per_second': 4.19, 'train_loss': 0.16484664735339938, 'epoch': 3.0}
# {'train_runtime': 3.5263, 'train_samples_per_second': 51.045, 'train_steps_per_second': 6.806, 'train_loss': 0.13782774408658346, 'epoch': 3.0}
# {'train_runtime': 3.1725, 'train_samples_per_second': 47.281, 'train_steps_per_second': 6.619, 'train_loss': 0.1103389717283703, 'epoch': 3.0}
# {'train_runtime': 4.3322, 'train_samples_per_second': 41.549, 'train_steps_per_second': 5.54, 'train_loss': 0.135369211435318, 'epoch': 3.0}
# {'train_runtime': 4.0158, 'train_samples_per_second': 44.823, 'train_steps_per_second': 5.976, 'train_loss': 0.11157964666684468, 'epoch': 3.0}
# {'train_runtime': 4.1391, 'train_samples_per_second': 43.488, 'train_steps_per_second': 5.798, 'train_loss': 0.09226983785629272, 'epoch': 3.0}
# {'train_runtime': 4.9563, 'train_samples_per_second': 36.317, 'train_steps_per_second': 4.842, 'train_loss': 0.1308343211809794, 'epoch': 3.0}
# {'train_runtime': 4.328, 'train_samples_per_second': 41.59, 'train_steps_per_second': 5.545, 'train_loss': 0.11901866396268208, 'epoch': 3.0}
# {'train_runtime': 3.0808, 'train_samples_per_second': 48.689, 'train_steps_per_second': 6.816, 'train_loss': 0.09254835333142962, 'epoch': 3.0}
# {'train_runtime': 3.0884, 'train_samples_per_second': 48.568, 'train_steps_per_second': 6.8, 'train_loss': 0.16020438784644717, 'epoch': 3.0}
# {'train_runtime': 2.9188, 'train_samples_per_second': 51.39, 'train_steps_per_second': 7.195, 'train_loss': 0.16417211578005836, 'epoch': 3.0}
# {'train_runtime': 4.1514, 'train_samples_per_second': 43.359, 'train_steps_per_second': 5.781, 'train_loss': 0.09972838560740153, 'epoch': 3.0}
# {'train_runtime': 3.6161, 'train_samples_per_second': 41.482, 'train_steps_per_second': 5.807, 'train_loss': 0.09609258742559523, 'epoch': 3.0}
# {'train_runtime': 3.5285, 'train_samples_per_second': 42.511, 'train_steps_per_second': 5.952, 'train_loss': 0.10869941257295154, 'epoch': 3.0}
# {'train_runtime': 3.6447, 'train_samples_per_second': 49.386, 'train_steps_per_second': 6.585, 'train_loss': 0.12497330705324809, 'epoch': 3.0}
# {'train_runtime': 3.4679, 'train_samples_per_second': 43.253, 'train_steps_per_second': 6.055, 'train_loss': 0.09417433398110527, 'epoch': 3.0}
# {'train_runtime': 4.1752, 'train_samples_per_second': 50.297, 'train_steps_per_second': 6.467, 'train_loss': 0.10890075895521376, 'epoch': 3.0}
# {'train_runtime': 3.4428, 'train_samples_per_second': 60.997, 'train_steps_per_second': 7.843, 'train_loss': 0.17031196311668115, 'epoch': 3.0}
# {'train_runtime': 3.1536, 'train_samples_per_second': 57.078, 'train_steps_per_second': 7.61, 'train_loss': 0.12827841440836588, 'epoch': 3.0}
# {'train_runtime': 3.1337, 'train_samples_per_second': 57.44, 'train_steps_per_second': 7.659, 'train_loss': 0.14988082647323608, 'epoch': 3.0}
# {'train_runtime': 4.1726, 'train_samples_per_second': 43.139, 'train_steps_per_second': 5.752, 'train_loss': 0.11379405856132507, 'epoch': 3.0}
# {'train_runtime': 2.9929, 'train_samples_per_second': 60.142, 'train_steps_per_second': 8.019, 'train_loss': 0.11866504947344463, 'epoch': 3.0}
# {'train_runtime': 2.0388, 'train_samples_per_second': 58.858, 'train_steps_per_second': 7.357, 'train_loss': 0.719717280069987, 'epoch': 3.0}
# {'train_runtime': 3.0221, 'train_samples_per_second': 69.488, 'train_steps_per_second': 8.934, 'train_loss': 0.231493526034885, 'epoch': 3.0}
# {'train_runtime': 2.5406, 'train_samples_per_second': 59.041, 'train_steps_per_second': 8.266, 'train_loss': 0.22121272768293107, 'epoch': 3.0}
# {'train_runtime': 3.1914, 'train_samples_per_second': 56.402, 'train_steps_per_second': 7.52, 'train_loss': 0.1785295605659485, 'epoch': 3.0}
# {'train_runtime': 4.4047, 'train_samples_per_second': 40.865, 'train_steps_per_second': 5.449, 'train_loss': 0.05349628130594889, 'epoch': 3.0}
# {'train_runtime': 3.4543, 'train_samples_per_second': 43.425, 'train_steps_per_second': 6.079, 'train_loss': 0.10477095558529809, 'epoch': 3.0}
# {'train_runtime': 4.2714, 'train_samples_per_second': 42.141, 'train_steps_per_second': 5.619, 'train_loss': 0.14959456523259482, 'epoch': 3.0}
# {'train_runtime': 3.1498, 'train_samples_per_second': 57.147, 'train_steps_per_second': 7.62, 'train_loss': 0.17288909355799356, 'epoch': 3.0}
# {'train_runtime': 3.1301, 'train_samples_per_second': 57.507, 'train_steps_per_second': 7.668, 'train_loss': 0.21316683292388916, 'epoch': 3.0}
# {'train_runtime': 3.2015, 'train_samples_per_second': 65.595, 'train_steps_per_second': 8.434, 'train_loss': 0.2111222125865795, 'epoch': 3.0}
# {'train_runtime': 4.3177, 'train_samples_per_second': 34.74, 'train_steps_per_second': 4.864, 'train_loss': 0.11397441228230794, 'epoch': 3.0}
# {'train_runtime': 5.231, 'train_samples_per_second': 28.675, 'train_steps_per_second': 4.015, 'train_loss': 0.10445779845828101, 'epoch': 3.0}
# {'train_runtime': 3.5574, 'train_samples_per_second': 50.598, 'train_steps_per_second': 6.746, 'train_loss': 0.11956871549288432, 'epoch': 3.0}
# {'train_runtime': 4.0171, 'train_samples_per_second': 44.809, 'train_steps_per_second': 5.975, 'train_loss': 0.1872546672821045, 'epoch': 3.0}
# {'train_runtime': 5.0302, 'train_samples_per_second': 35.784, 'train_steps_per_second': 4.771, 'train_loss': 0.20803056160608926, 'epoch': 3.0}
# {'train_runtime': 3.174, 'train_samples_per_second': 56.71, 'train_steps_per_second': 7.561, 'train_loss': 0.20119299491246542, 'epoch': 3.0}
# {'train_runtime': 5.0646, 'train_samples_per_second': 29.617, 'train_steps_per_second': 4.146, 'train_loss': 0.11353157815479097, 'epoch': 3.0}
# {'train_runtime': 3.4904, 'train_samples_per_second': 51.57, 'train_steps_per_second': 6.876, 'train_loss': 0.12115272879600525, 'epoch': 3.0}
# {'train_runtime': 3.4187, 'train_samples_per_second': 52.652, 'train_steps_per_second': 7.02, 'train_loss': 0.14297406872113547, 'epoch': 3.0}
# {'train_runtime': 3.6027, 'train_samples_per_second': 49.963, 'train_steps_per_second': 6.662, 'train_loss': 0.15201793114344278, 'epoch': 3.0}
# {'train_runtime': 2.6431, 'train_samples_per_second': 45.401, 'train_steps_per_second': 5.675, 'train_loss': 0.13886361122131347, 'epoch': 3.0}
# {'train_runtime': 2.8843, 'train_samples_per_second': 62.407, 'train_steps_per_second': 8.321, 'train_loss': 0.16587257385253906, 'epoch': 3.0}
# {'train_runtime': 3.2117, 'train_samples_per_second': 56.045, 'train_steps_per_second': 7.473, 'train_loss': 0.12715072433153787, 'epoch': 3.0}
# {'train_runtime': 3.5378, 'train_samples_per_second': 50.878, 'train_steps_per_second': 6.784, 'train_loss': 0.14130976796150208, 'epoch': 3.0}
# {'train_runtime': 1.819, 'train_samples_per_second': 65.971, 'train_steps_per_second': 8.246, 'train_loss': 0.12190595467885336, 'epoch': 3.0}
# {'train_runtime': 2.9445, 'train_samples_per_second': 50.942, 'train_steps_per_second': 7.132, 'train_loss': 0.12882097562154135, 'epoch': 3.0}
# {'train_runtime': 2.5535, 'train_samples_per_second': 58.742, 'train_steps_per_second': 8.224, 'train_loss': 0.19215411231631324, 'epoch': 3.0}
# {'train_runtime': 2.6781, 'train_samples_per_second': 56.011, 'train_steps_per_second': 7.842, 'train_loss': 0.15088227816990443, 'epoch': 3.0}
# {'train_runtime': 3.1218, 'train_samples_per_second': 57.659, 'train_steps_per_second': 7.688, 'train_loss': 0.1283553143342336, 'epoch': 3.0}
# {'train_runtime': 3.0071, 'train_samples_per_second': 49.882, 'train_steps_per_second': 6.983, 'train_loss': 0.11699869519188291, 'epoch': 3.0}
# {'train_runtime': 3.6384, 'train_samples_per_second': 49.473, 'train_steps_per_second': 6.596, 'train_loss': 0.07036443054676056, 'epoch': 3.0}
# {'train_runtime': 3.5338, 'train_samples_per_second': 42.447, 'train_steps_per_second': 5.943, 'train_loss': 0.15361693927219935, 'epoch': 3.0}
# {'train_runtime': 4.1196, 'train_samples_per_second': 65.541, 'train_steps_per_second': 8.739, 'train_loss': 0.16369928254021537, 'epoch': 3.0}
# {'train_runtime': 2.7001, 'train_samples_per_second': 55.554, 'train_steps_per_second': 7.778, 'train_loss': 0.2766759509132022, 'epoch': 3.0}
# {'train_runtime': 2.2479, 'train_samples_per_second': 53.383, 'train_steps_per_second': 6.673, 'train_loss': 0.20006394386291504, 'epoch': 3.0}
# {'train_runtime': 3.5987, 'train_samples_per_second': 50.018, 'train_steps_per_second': 6.669, 'train_loss': 0.07580942412217458, 'epoch': 3.0}
# {'train_runtime': 3.2078, 'train_samples_per_second': 56.113, 'train_steps_per_second': 7.482, 'train_loss': 0.23715470234553018, 'epoch': 3.0}
# {'train_runtime': 3.9778, 'train_samples_per_second': 45.251, 'train_steps_per_second': 6.033, 'train_loss': 0.07595419883728027, 'epoch': 3.0}
# {'train_runtime': 4.9905, 'train_samples_per_second': 36.069, 'train_steps_per_second': 4.809, 'train_loss': 0.11419746279716492, 'epoch': 3.0}
# {'train_runtime': 2.278, 'train_samples_per_second': 52.679, 'train_steps_per_second': 6.585, 'train_loss': 0.3092248280843099, 'epoch': 3.0}
# {'train_runtime': 2.7796, 'train_samples_per_second': 53.965, 'train_steps_per_second': 7.555, 'train_loss': 0.17460491543724424, 'epoch': 3.0}
# {'train_runtime': 2.8352, 'train_samples_per_second': 63.487, 'train_steps_per_second': 8.465, 'train_loss': 0.3985738356908162, 'epoch': 3.0}
# {'train_runtime': 2.711, 'train_samples_per_second': 55.331, 'train_steps_per_second': 7.746, 'train_loss': 0.13970988137381418, 'epoch': 3.0}
# {'train_runtime': 2.6027, 'train_samples_per_second': 57.633, 'train_steps_per_second': 8.069, 'train_loss': 0.29159723009381977, 'epoch': 3.0}
# {'train_runtime': 3.5259, 'train_samples_per_second': 51.051, 'train_steps_per_second': 6.807, 'train_loss': 0.3035605549812317, 'epoch': 3.0}
# {'train_runtime': 3.994, 'train_samples_per_second': 45.068, 'train_steps_per_second': 6.009, 'train_loss': 0.09343419472376506, 'epoch': 3.0}
# {'train_runtime': 2.8156, 'train_samples_per_second': 53.274, 'train_steps_per_second': 7.458, 'train_loss': 0.1140986510685512, 'epoch': 3.0}
# {'train_runtime': 3.4837, 'train_samples_per_second': 60.281, 'train_steps_per_second': 7.75, 'train_loss': 0.1495232935304995, 'epoch': 3.0}
# {'train_runtime': 3.3155, 'train_samples_per_second': 54.29, 'train_steps_per_second': 7.239, 'train_loss': 0.23877362410227457, 'epoch': 3.0}

# %%
en_fa_scores
# Out:
# [-0.11538461538461539,
#  -0.16666666666666666,
#  -0.3333333333333333,
#  -0.125,
#  -0.14285714285714285,
#  -0.047619047619047616,
#  -0.05,
#  -0.2727272727272727,
#  -0.07142857142857142,
#  -0.1,
#  -0.3076923076923077,
#  0.0,
#  -0.42857142857142855,
#  -0.2222222222222222,
#  -0.42857142857142855,
#  -0.08695652173913043,
#  -0.1111111111111111,
#  -0.2,
#  0.07692307692307693,
#  -0.125,
#  -0.13333333333333333,
#  0.07692307692307693,
#  -0.1111111111111111,
#  -0.2,
#  -0.11764705882352941,
#  -0.5,
#  -0.6,
#  -0.2,
#  -0.17647058823529413,
#  -0.26666666666666666,
#  -0.7222222222222222,
#  0.0,
#  -0.16666666666666666,
#  -0.5333333333333333,
#  0.0,
#  -0.2,
#  -0.3333333333333333,
#  -0.25,
#  0.25,
#  -0.4444444444444444,
#  -0.125,
#  -0.14285714285714285,
#  -0.1,
#  -0.14285714285714285,
#  0.0,
#  -0.1,
#  -0.5714285714285714,
#  -0.16666666666666666,
#  -0.375,
#  -0.25,
#  -0.09090909090909091,
#  0.0,
#  -0.25925925925925924,
#  0.125,
#  -0.05555555555555555,
#  -0.21739130434782608,
#  0.12,
#  -0.06666666666666667,
#  -0.07692307692307693,
#  -0.125,
#  0.0,
#  -0.038461538461538464,
#  -0.21428571428571427,
#  -0.08,
#  -0.2727272727272727,
#  -0.1111111111111111,
#  -0.3076923076923077,
#  0.0,
#  0.0,
#  -0.2857142857142857,
#  -0.18181818181818182,
#  -0.0625,
#  -0.3793103448275862,
#  -0.25,
#  -0.23076923076923078,
#  -0.4,
#  0.05555555555555555,
#  -0.1111111111111111,
#  0.0,
#  -0.08333333333333333,
#  -0.4166666666666667,
#  -0.4,
#  0.25,
#  -0.25,
#  0.25,
#  -0.2222222222222222,
#  -0.21052631578947367,
#  -0.06666666666666667,
#  -0.18181818181818182,
#  -0.2857142857142857,
#  0.09090909090909091,
#  -0.4,
#  0.0,
#  -0.2727272727272727,
#  0.15384615384615385,
#  0.0,
#  0.058823529411764705,
#  -0.2857142857142857,
#  -0.2,
#  -0.3125,
#  0.3,
#  -0.29411764705882354,
#  0.07142857142857142,
#  -0.13636363636363635,
#  0.0,
#  -0.05555555555555555,
#  -0.07142857142857142,
#  -0.037037037037037035,
#  -0.09090909090909091,
#  0.16666666666666666,
#  -0.1111111111111111,
#  -0.17647058823529413,
#  -0.26666666666666666,
#  -0.2,
#  0.09090909090909091,
#  0.0,
#  -0.25,
#  0.0,
#  -0.13333333333333333,
#  0.0,
#  0.0,
#  -0.09523809523809523,
#  0.0,
#  -0.375,
#  0.16666666666666666,
#  -0.18181818181818182,
#  -0.18181818181818182,
#  -0.25,
#  -0.15384615384615385,
#  -0.1111111111111111,
#  -0.30434782608695654,
#  -0.11764705882352941,
#  -0.2692307692307692,
#  -0.20833333333333334,
#  -0.09090909090909091,
#  -0.08333333333333333,
#  -0.0967741935483871,
#  -0.14285714285714285,
#  0.0,
#  0.0,
#  -0.13043478260869565,
#  -0.36,
#  -0.42857142857142855,
#  -0.21568627450980393,
#  0.0,
#  -0.34285714285714286,
#  -0.22727272727272727,
#  -0.2,
#  -0.08333333333333333,
#  0.0,
#  -0.23076923076923078,
#  -0.08333333333333333,
#  0.0,
#  0.0,
#  -0.11764705882352941,
#  0.0,
#  0.0,
#  0.06666666666666667,
#  0.1,
#  -0.2631578947368421,
#  -0.047619047619047616,
#  -0.23809523809523808,
#  0.0,
#  -0.18181818181818182,
#  -0.15384615384615385,
#  -0.21428571428571427,
#  -0.13333333333333333,
#  0.0,
#  0.0,
#  -0.05263157894736842,
#  -0.2777777777777778,
#  0.0,
#  -0.07142857142857142,
#  0.07692307692307693,
#  -0.08333333333333333,
#  -0.07692307692307693,
#  -0.11764705882352941,
#  -0.125,
#  -0.23809523809523808,
#  0.0,
#  -0.2777777777777778,
#  -0.047619047619047616,
#  -0.4666666666666667,
#  0.0,
#  -0.2222222222222222,
#  0.0,
#  0.0,
#  -0.09090909090909091,
#  0.0,
#  -0.17647058823529413,
#  -0.2857142857142857,
#  -0.12903225806451613,
#  0.0,
#  0.0,
#  -0.06666666666666667,
#  -0.4,
#  -0.35,
#  0.0,
#  0.0,
#  -0.125,
#  -0.14285714285714285,
#  0.0,
#  0.0,
#  -0.07692307692307693,
#  -0.42857142857142855,
#  -0.14285714285714285,
#  -0.23076923076923078,
#  -0.13333333333333333,
#  -0.18181818181818182,
#  -0.25,
#  0.0,
#  -0.0625,
#  0.0,
#  -0.07692307692307693,
#  -0.21428571428571427,
#  -0.25,
#  -0.13333333333333333,
#  0.0,
#  -0.14285714285714285,
#  0.0,
#  -0.14285714285714285,
#  0.125,
#  0.027777777777777776,
#  -0.2,
#  -0.6666666666666666,
#  0.125,
#  -0.05263157894736842,
#  -0.14285714285714285,
#  -0.05,
#  -0.02857142857142857,
#  -0.23076923076923078,
#  -0.16666666666666666,
#  -0.125,
#  -0.13333333333333333,
#  -0.18181818181818182,
#  -0.15384615384615385,
#  -0.09523809523809523,
#  -0.2857142857142857,
#  -0.1111111111111111,
#  0.3333333333333333,
#  -0.36363636363636365,
#  -0.1,
#  -0.1,
#  -0.2222222222222222,
#  -0.296875,
#  -0.3,
#  0.0,
#  -0.3333333333333333,
#  -0.2,
#  -0.5,
#  0.0,
#  -0.2222222222222222,
#  0.7142857142857143,
#  0.0,
#  -0.42857142857142855,
#  -0.16666666666666666,
#  -0.09090909090909091,
#  -0.17647058823529413,
#  0.0,
#  -0.2857142857142857,
#  -0.3,
#  0.04,
#  -0.14285714285714285,
#  0.06666666666666667,
#  -0.14285714285714285,
#  -0.2,
#  0.0,
#  -0.25,
#  -0.16666666666666666,
#  -0.07692307692307693,
#  -0.4,
#  -0.0625,
#  -0.13333333333333333,
#  -0.13333333333333333,
#  -0.25,
#  0.0,
#  0.0,
#  -0.6,
#  0.09090909090909091,
#  -0.46153846153846156,
#  -0.2857142857142857,
#  -0.07142857142857142,
#  -0.5882352941176471,
#  0.2,
#  -0.1,
#  -0.14285714285714285,
#  -0.16666666666666666,
#  -0.2727272727272727,
#  -0.125,
#  -0.21428571428571427,
#  -0.15384615384615385,
#  -0.07142857142857142,
#  0.0,
#  -0.18181818181818182,
#  -0.42857142857142855,
#  -0.07692307692307693,
#  -0.2727272727272727,
#  -0.07692307692307693,
#  -0.38461538461538464,
#  -0.3333333333333333]

# %%
# en_fa_data = {}
# en_fa_data['BLANC_tune_en_fa_translation'] = en_fa_scores
# add_results_to_json(en_fa_data)
